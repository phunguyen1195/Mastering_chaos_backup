# %%
import gym
import Lorenz_envs
import matplotlib.pyplot as plt
import numpy as np
import time
import torch
import warnings
import copy 



from IPython import display
from torch.distributions import MultivariateNormal
from torch.optim import Adam
from torch.nn import Linear, Module, MSELoss, ReLU, Sequential

warnings.filterwarnings("ignore")
# Out:
# /home/phu/Dropbox/general_backup/anaconda3/envs/gen_env/lib/python3.10/site-packages/gym/envs/registration.py:216: UserWarning: WARN: Overriding environment ALE/Tetris-v5
#   logger.warn("Overriding environment {}".format(id))
# /home/phu/Dropbox/general_backup/anaconda3/envs/gen_env/lib/python3.10/site-packages/gym/envs/registration.py:216: UserWarning: WARN: Overriding environment ALE/Tetris-ram-v5
#   logger.warn("Overriding environment {}".format(id))
# /home/phu/Dropbox/general_backup/anaconda3/envs/gen_env/lib/python3.10/site-packages/gym/envs/registration.py:216: UserWarning: WARN: Overriding environment ALE/Pitfall2-v5
#   logger.warn("Overriding environment {}".format(id))
# /home/phu/Dropbox/general_backup/anaconda3/envs/gen_env/lib/python3.10/site-packages/gym/envs/registration.py:216: UserWarning: WARN: Overriding environment ALE/Pitfall2-ram-v5
#   logger.warn("Overriding environment {}".format(id))
# /home/phu/Dropbox/general_backup/anaconda3/envs/gen_env/lib/python3.10/site-packages/gym/envs/registration.py:216: UserWarning: WARN: Overriding environment ALE/LaserGates-v5
#   logger.warn("Overriding environment {}".format(id))
# /home/phu/Dropbox/general_backup/anaconda3/envs/gen_env/lib/python3.10/site-packages/gym/envs/registration.py:216: UserWarning: WARN: Overriding environment ALE/LaserGates-ram-v5
#   logger.warn("Overriding environment {}".format(id))
# /home/phu/Dropbox/general_backup/anaconda3/envs/gen_env/lib/python3.10/site-packages/gym/envs/registration.py:216: UserWarning: WARN: Overriding environment ALE/Freeway-v5
#   logger.warn("Overriding environment {}".format(id))
# /home/phu/Dropbox/general_backup/anaconda3/envs/gen_env/lib/python3.10/site-packages/gym/envs/registration.py:216: UserWarning: WARN: Overriding environment ALE/Freeway-ram-v5
#   logger.warn("Overriding environment {}".format(id))
# /home/phu/Dropbox/general_backup/anaconda3/envs/gen_env/lib/python3.10/site-packages/gym/envs/registration.py:216: UserWarning: WARN: Overriding environment ALE/MrDo-v5
#   logger.warn("Overriding environment {}".format(id))
# /home/phu/Dropbox/general_backup/anaconda3/envs/gen_env/lib/python3.10/site-packages/gym/envs/registration.py:216: UserWarning: WARN: Overriding environment ALE/MrDo-ram-v5
#   logger.warn("Overriding environment {}".format(id))
# /home/phu/Dropbox/general_backup/anaconda3/envs/gen_env/lib/python3.10/site-packages/gym/envs/registration.py:216: UserWarning: WARN: Overriding environment ALE/Assault-v5
#   logger.warn("Overriding environment {}".format(id))
# /home/phu/Dropbox/general_backup/anaconda3/envs/gen_env/lib/python3.10/site-packages/gym/envs/registration.py:216: UserWarning: WARN: Overriding environment ALE/Assault-ram-v5
#   logger.warn("Overriding environment {}".format(id))
# /home/phu/Dropbox/general_backup/anaconda3/envs/gen_env/lib/python3.10/site-packages/gym/envs/registration.py:216: UserWarning: WARN: Overriding environment ALE/Pooyan-v5
#   logger.warn("Overriding environment {}".format(id))
# /home/phu/Dropbox/general_backup/anaconda3/envs/gen_env/lib/python3.10/site-packages/gym/envs/registration.py:216: UserWarning: WARN: Overriding environment ALE/Pooyan-ram-v5
#   logger.warn("Overriding environment {}".format(id))
# /home/phu/Dropbox/general_backup/anaconda3/envs/gen_env/lib/python3.10/site-packages/gym/envs/registration.py:216: UserWarning: WARN: Overriding environment ALE/Othello-v5
#   logger.warn("Overriding environment {}".format(id))
# /home/phu/Dropbox/general_backup/anaconda3/envs/gen_env/lib/python3.10/site-packages/gym/envs/registration.py:216: UserWarning: WARN: Overriding environment ALE/Othello-ram-v5
#   logger.warn("Overriding environment {}".format(id))
# /home/phu/Dropbox/general_backup/anaconda3/envs/gen_env/lib/python3.10/site-packages/gym/envs/registration.py:216: UserWarning: WARN: Overriding environment ALE/HauntedHouse-v5
#   logger.warn("Overriding environment {}".format(id))
# /home/phu/Dropbox/general_backup/anaconda3/envs/gen_env/lib/python3.10/site-packages/gym/envs/registration.py:216: UserWarning: WARN: Overriding environment ALE/HauntedHouse-ram-v5
#   logger.warn("Overriding environment {}".format(id))
# /home/phu/Dropbox/general_backup/anaconda3/envs/gen_env/lib/python3.10/site-packages/gym/envs/registration.py:216: UserWarning: WARN: Overriding environment ALE/TicTacToe3D-v5
#   logger.warn("Overriding environment {}".format(id))
# /home/phu/Dropbox/general_backup/anaconda3/envs/gen_env/lib/python3.10/site-packages/gym/envs/registration.py:216: UserWarning: WARN: Overriding environment ALE/TicTacToe3D-ram-v5
#   logger.warn("Overriding environment {}".format(id))
# /home/phu/Dropbox/general_backup/anaconda3/envs/gen_env/lib/python3.10/site-packages/gym/envs/registration.py:216: UserWarning: WARN: Overriding environment ALE/Turmoil-v5
#   logger.warn("Overriding environment {}".format(id))
# /home/phu/Dropbox/general_backup/anaconda3/envs/gen_env/lib/python3.10/site-packages/gym/envs/registration.py:216: UserWarning: WARN: Overriding environment ALE/Turmoil-ram-v5
#   logger.warn("Overriding environment {}".format(id))
# /home/phu/Dropbox/general_backup/anaconda3/envs/gen_env/lib/python3.10/site-packages/gym/envs/registration.py:216: UserWarning: WARN: Overriding environment ALE/MsPacman-v5
#   logger.warn("Overriding environment {}".format(id))
# /home/phu/Dropbox/general_backup/anaconda3/envs/gen_env/lib/python3.10/site-packages/gym/envs/registration.py:216: UserWarning: WARN: Overriding environment ALE/MsPacman-ram-v5
#   logger.warn("Overriding environment {}".format(id))
# /home/phu/Dropbox/general_backup/anaconda3/envs/gen_env/lib/python3.10/site-packages/gym/envs/registration.py:216: UserWarning: WARN: Overriding environment ALE/CrazyClimber-v5
#   logger.warn("Overriding environment {}".format(id))
# /home/phu/Dropbox/general_backup/anaconda3/envs/gen_env/lib/python3.10/site-packages/gym/envs/registration.py:216: UserWarning: WARN: Overriding environment ALE/CrazyClimber-ram-v5
#   logger.warn("Overriding environment {}".format(id))
# /home/phu/Dropbox/general_backup/anaconda3/envs/gen_env/lib/python3.10/site-packages/gym/envs/registration.py:216: UserWarning: WARN: Overriding environment ALE/Tutankham-v5
#   logger.warn("Overriding environment {}".format(id))
# /home/phu/Dropbox/general_backup/anaconda3/envs/gen_env/lib/python3.10/site-packages/gym/envs/registration.py:216: UserWarning: WARN: Overriding environment ALE/Tutankham-ram-v5
#   logger.warn("Overriding environment {}".format(id))
# /home/phu/Dropbox/general_backup/anaconda3/envs/gen_env/lib/python3.10/site-packages/gym/envs/registration.py:216: UserWarning: WARN: Overriding environment ALE/Pitfall-v5
#   logger.warn("Overriding environment {}".format(id))
# /home/phu/Dropbox/general_backup/anaconda3/envs/gen_env/lib/python3.10/site-packages/gym/envs/registration.py:216: UserWarning: WARN: Overriding environment ALE/Pitfall-ram-v5
#   logger.warn("Overriding environment {}".format(id))
# /home/phu/Dropbox/general_backup/anaconda3/envs/gen_env/lib/python3.10/site-packages/gym/envs/registration.py:216: UserWarning: WARN: Overriding environment ALE/BankHeist-v5
#   logger.warn("Overriding environment {}".format(id))
# /home/phu/Dropbox/general_backup/anaconda3/envs/gen_env/lib/python3.10/site-packages/gym/envs/registration.py:216: UserWarning: WARN: Overriding environment ALE/BankHeist-ram-v5
#   logger.warn("Overriding environment {}".format(id))
# /home/phu/Dropbox/general_backup/anaconda3/envs/gen_env/lib/python3.10/site-packages/gym/envs/registration.py:216: UserWarning: WARN: Overriding environment ALE/Koolaid-v5
#   logger.warn("Overriding environment {}".format(id))
# /home/phu/Dropbox/general_backup/anaconda3/envs/gen_env/lib/python3.10/site-packages/gym/envs/registration.py:216: UserWarning: WARN: Overriding environment ALE/Koolaid-ram-v5
#   logger.warn("Overriding environment {}".format(id))
# /home/phu/Dropbox/general_backup/anaconda3/envs/gen_env/lib/python3.10/site-packages/gym/envs/registration.py:216: UserWarning: WARN: Overriding environment ALE/Galaxian-v5
#   logger.warn("Overriding environment {}".format(id))
# /home/phu/Dropbox/general_backup/anaconda3/envs/gen_env/lib/python3.10/site-packages/gym/envs/registration.py:216: UserWarning: WARN: Overriding environment ALE/Galaxian-ram-v5
#   logger.warn("Overriding environment {}".format(id))
# /home/phu/Dropbox/general_backup/anaconda3/envs/gen_env/lib/python3.10/site-packages/gym/envs/registration.py:216: UserWarning: WARN: Overriding environment ALE/Tennis-v5
#   logger.warn("Overriding environment {}".format(id))
# /home/phu/Dropbox/general_backup/anaconda3/envs/gen_env/lib/python3.10/site-packages/gym/envs/registration.py:216: UserWarning: WARN: Overriding environment ALE/Tennis-ram-v5
#   logger.warn("Overriding environment {}".format(id))
# /home/phu/Dropbox/general_backup/anaconda3/envs/gen_env/lib/python3.10/site-packages/gym/envs/registration.py:216: UserWarning: WARN: Overriding environment ALE/YarsRevenge-v5
#   logger.warn("Overriding environment {}".format(id))
# /home/phu/Dropbox/general_backup/anaconda3/envs/gen_env/lib/python3.10/site-packages/gym/envs/registration.py:216: UserWarning: WARN: Overriding environment ALE/YarsRevenge-ram-v5
#   logger.warn("Overriding environment {}".format(id))
# /home/phu/Dropbox/general_backup/anaconda3/envs/gen_env/lib/python3.10/site-packages/gym/envs/registration.py:216: UserWarning: WARN: Overriding environment ALE/Atlantis2-v5
#   logger.warn("Overriding environment {}".format(id))
# /home/phu/Dropbox/general_backup/anaconda3/envs/gen_env/lib/python3.10/site-packages/gym/envs/registration.py:216: UserWarning: WARN: Overriding environment ALE/Atlantis2-ram-v5
#   logger.warn("Overriding environment {}".format(id))
# /home/phu/Dropbox/general_backup/anaconda3/envs/gen_env/lib/python3.10/site-packages/gym/envs/registration.py:216: UserWarning: WARN: Overriding environment ALE/Atlantis-v5
#   logger.warn("Overriding environment {}".format(id))
# /home/phu/Dropbox/general_backup/anaconda3/envs/gen_env/lib/python3.10/site-packages/gym/envs/registration.py:216: UserWarning: WARN: Overriding environment ALE/Atlantis-ram-v5
#   logger.warn("Overriding environment {}".format(id))
# /home/phu/Dropbox/general_backup/anaconda3/envs/gen_env/lib/python3.10/site-packages/gym/envs/registration.py:216: UserWarning: WARN: Overriding environment ALE/Carnival-v5
#   logger.warn("Overriding environment {}".format(id))
# /home/phu/Dropbox/general_backup/anaconda3/envs/gen_env/lib/python3.10/site-packages/gym/envs/registration.py:216: UserWarning: WARN: Overriding environment ALE/Carnival-ram-v5
#   logger.warn("Overriding environment {}".format(id))
# /home/phu/Dropbox/general_backup/anaconda3/envs/gen_env/lib/python3.10/site-packages/gym/envs/registration.py:216: UserWarning: WARN: Overriding environment ALE/Amidar-v5
#   logger.warn("Overriding environment {}".format(id))
# /home/phu/Dropbox/general_backup/anaconda3/envs/gen_env/lib/python3.10/site-packages/gym/envs/registration.py:216: UserWarning: WARN: Overriding environment ALE/Amidar-ram-v5
#   logger.warn("Overriding environment {}".format(id))
# /home/phu/Dropbox/general_backup/anaconda3/envs/gen_env/lib/python3.10/site-packages/gym/envs/registration.py:216: UserWarning: WARN: Overriding environment ALE/JourneyEscape-v5
#   logger.warn("Overriding environment {}".format(id))
# /home/phu/Dropbox/general_backup/anaconda3/envs/gen_env/lib/python3.10/site-packages/gym/envs/registration.py:216: UserWarning: WARN: Overriding environment ALE/JourneyEscape-ram-v5
#   logger.warn("Overriding environment {}".format(id))
# /home/phu/Dropbox/general_backup/anaconda3/envs/gen_env/lib/python3.10/site-packages/gym/envs/registration.py:216: UserWarning: WARN: Overriding environment ALE/MontezumaRevenge-v5
#   logger.warn("Overriding environment {}".format(id))
# /home/phu/Dropbox/general_backup/anaconda3/envs/gen_env/lib/python3.10/site-packages/gym/envs/registration.py:216: UserWarning: WARN: Overriding environment ALE/MontezumaRevenge-ram-v5
#   logger.warn("Overriding environment {}".format(id))
# /home/phu/Dropbox/general_backup/anaconda3/envs/gen_env/lib/python3.10/site-packages/gym/envs/registration.py:216: UserWarning: WARN: Overriding environment ALE/Videochess-v5
#   logger.warn("Overriding environment {}".format(id))
# /home/phu/Dropbox/general_backup/anaconda3/envs/gen_env/lib/python3.10/site-packages/gym/envs/registration.py:216: UserWarning: WARN: Overriding environment ALE/Videochess-ram-v5
#   logger.warn("Overriding environment {}".format(id))
# /home/phu/Dropbox/general_backup/anaconda3/envs/gen_env/lib/python3.10/site-packages/gym/envs/registration.py:216: UserWarning: WARN: Overriding environment ALE/Qbert-v5
#   logger.warn("Overriding environment {}".format(id))
# /home/phu/Dropbox/general_backup/anaconda3/envs/gen_env/lib/python3.10/site-packages/gym/envs/registration.py:216: UserWarning: WARN: Overriding environment ALE/Qbert-ram-v5
#   logger.warn("Overriding environment {}".format(id))
# /home/phu/Dropbox/general_backup/anaconda3/envs/gen_env/lib/python3.10/site-packages/gym/envs/registration.py:216: UserWarning: WARN: Overriding environment ALE/BattleZone-v5
#   logger.warn("Overriding environment {}".format(id))
# /home/phu/Dropbox/general_backup/anaconda3/envs/gen_env/lib/python3.10/site-packages/gym/envs/registration.py:216: UserWarning: WARN: Overriding environment ALE/BattleZone-ram-v5
#   logger.warn("Overriding environment {}".format(id))
# /home/phu/Dropbox/general_backup/anaconda3/envs/gen_env/lib/python3.10/site-packages/gym/envs/registration.py:216: UserWarning: WARN: Overriding environment ALE/Enduro-v5
#   logger.warn("Overriding environment {}".format(id))
# /home/phu/Dropbox/general_backup/anaconda3/envs/gen_env/lib/python3.10/site-packages/gym/envs/registration.py:216: UserWarning: WARN: Overriding environment ALE/Enduro-ram-v5
#   logger.warn("Overriding environment {}".format(id))
# /home/phu/Dropbox/general_backup/anaconda3/envs/gen_env/lib/python3.10/site-packages/gym/envs/registration.py:216: UserWarning: WARN: Overriding environment ALE/Klax-v5
#   logger.warn("Overriding environment {}".format(id))
# /home/phu/Dropbox/general_backup/anaconda3/envs/gen_env/lib/python3.10/site-packages/gym/envs/registration.py:216: UserWarning: WARN: Overriding environment ALE/Klax-ram-v5
#   logger.warn("Overriding environment {}".format(id))
# /home/phu/Dropbox/general_backup/anaconda3/envs/gen_env/lib/python3.10/site-packages/gym/envs/registration.py:216: UserWarning: WARN: Overriding environment ALE/Adventure-v5
#   logger.warn("Overriding environment {}".format(id))
# /home/phu/Dropbox/general_backup/anaconda3/envs/gen_env/lib/python3.10/site-packages/gym/envs/registration.py:216: UserWarning: WARN: Overriding environment ALE/Adventure-ram-v5
#   logger.warn("Overriding environment {}".format(id))
# /home/phu/Dropbox/general_backup/anaconda3/envs/gen_env/lib/python3.10/site-packages/gym/envs/registration.py:216: UserWarning: WARN: Overriding environment ALE/Gopher-v5
#   logger.warn("Overriding environment {}".format(id))
# /home/phu/Dropbox/general_backup/anaconda3/envs/gen_env/lib/python3.10/site-packages/gym/envs/registration.py:216: UserWarning: WARN: Overriding environment ALE/Gopher-ram-v5
#   logger.warn("Overriding environment {}".format(id))
# /home/phu/Dropbox/general_backup/anaconda3/envs/gen_env/lib/python3.10/site-packages/gym/envs/registration.py:216: UserWarning: WARN: Overriding environment ALE/WizardOfWor-v5
#   logger.warn("Overriding environment {}".format(id))
# /home/phu/Dropbox/general_backup/anaconda3/envs/gen_env/lib/python3.10/site-packages/gym/envs/registration.py:216: UserWarning: WARN: Overriding environment ALE/WizardOfWor-ram-v5
#   logger.warn("Overriding environment {}".format(id))
# /home/phu/Dropbox/general_backup/anaconda3/envs/gen_env/lib/python3.10/site-packages/gym/envs/registration.py:216: UserWarning: WARN: Overriding environment ALE/Asterix-v5
#   logger.warn("Overriding environment {}".format(id))
# /home/phu/Dropbox/general_backup/anaconda3/envs/gen_env/lib/python3.10/site-packages/gym/envs/registration.py:216: UserWarning: WARN: Overriding environment ALE/Asterix-ram-v5
#   logger.warn("Overriding environment {}".format(id))
# /home/phu/Dropbox/general_backup/anaconda3/envs/gen_env/lib/python3.10/site-packages/gym/envs/registration.py:216: UserWarning: WARN: Overriding environment ALE/RoadRunner-v5
#   logger.warn("Overriding environment {}".format(id))
# /home/phu/Dropbox/general_backup/anaconda3/envs/gen_env/lib/python3.10/site-packages/gym/envs/registration.py:216: UserWarning: WARN: Overriding environment ALE/RoadRunner-ram-v5
#   logger.warn("Overriding environment {}".format(id))
# /home/phu/Dropbox/general_backup/anaconda3/envs/gen_env/lib/python3.10/site-packages/gym/envs/registration.py:216: UserWarning: WARN: Overriding environment ALE/Kaboom-v5
#   logger.warn("Overriding environment {}".format(id))
# /home/phu/Dropbox/general_backup/anaconda3/envs/gen_env/lib/python3.10/site-packages/gym/envs/registration.py:216: UserWarning: WARN: Overriding environment ALE/Kaboom-ram-v5
#   logger.warn("Overriding environment {}".format(id))
# /home/phu/Dropbox/general_backup/anaconda3/envs/gen_env/lib/python3.10/site-packages/gym/envs/registration.py:216: UserWarning: WARN: Overriding environment ALE/Bowling-v5
#   logger.warn("Overriding environment {}".format(id))
# /home/phu/Dropbox/general_backup/anaconda3/envs/gen_env/lib/python3.10/site-packages/gym/envs/registration.py:216: UserWarning: WARN: Overriding environment ALE/Bowling-ram-v5
#   logger.warn("Overriding environment {}".format(id))
# /home/phu/Dropbox/general_backup/anaconda3/envs/gen_env/lib/python3.10/site-packages/gym/envs/registration.py:216: UserWarning: WARN: Overriding environment ALE/Pacman-v5
#   logger.warn("Overriding environment {}".format(id))
# /home/phu/Dropbox/general_backup/anaconda3/envs/gen_env/lib/python3.10/site-packages/gym/envs/registration.py:216: UserWarning: WARN: Overriding environment ALE/Pacman-ram-v5
#   logger.warn("Overriding environment {}".format(id))
# /home/phu/Dropbox/general_backup/anaconda3/envs/gen_env/lib/python3.10/site-packages/gym/envs/registration.py:216: UserWarning: WARN: Overriding environment ALE/Frostbite-v5
#   logger.warn("Overriding environment {}".format(id))
# /home/phu/Dropbox/general_backup/anaconda3/envs/gen_env/lib/python3.10/site-packages/gym/envs/registration.py:216: UserWarning: WARN: Overriding environment ALE/Frostbite-ram-v5
#   logger.warn("Overriding environment {}".format(id))
# /home/phu/Dropbox/general_backup/anaconda3/envs/gen_env/lib/python3.10/site-packages/gym/envs/registration.py:216: UserWarning: WARN: Overriding environment ALE/ElevatorAction-v5
#   logger.warn("Overriding environment {}".format(id))
# /home/phu/Dropbox/general_backup/anaconda3/envs/gen_env/lib/python3.10/site-packages/gym/envs/registration.py:216: UserWarning: WARN: Overriding environment ALE/ElevatorAction-ram-v5
#   logger.warn("Overriding environment {}".format(id))
# /home/phu/Dropbox/general_backup/anaconda3/envs/gen_env/lib/python3.10/site-packages/gym/envs/registration.py:216: UserWarning: WARN: Overriding environment ALE/Robotank-v5
#   logger.warn("Overriding environment {}".format(id))
# /home/phu/Dropbox/general_backup/anaconda3/envs/gen_env/lib/python3.10/site-packages/gym/envs/registration.py:216: UserWarning: WARN: Overriding environment ALE/Robotank-ram-v5
#   logger.warn("Overriding environment {}".format(id))
# /home/phu/Dropbox/general_backup/anaconda3/envs/gen_env/lib/python3.10/site-packages/gym/envs/registration.py:216: UserWarning: WARN: Overriding environment ALE/Asteroids-v5
#   logger.warn("Overriding environment {}".format(id))
# /home/phu/Dropbox/general_backup/anaconda3/envs/gen_env/lib/python3.10/site-packages/gym/envs/registration.py:216: UserWarning: WARN: Overriding environment ALE/Asteroids-ram-v5
#   logger.warn("Overriding environment {}".format(id))
# /home/phu/Dropbox/general_backup/anaconda3/envs/gen_env/lib/python3.10/site-packages/gym/envs/registration.py:216: UserWarning: WARN: Overriding environment ALE/DoubleDunk-v5
#   logger.warn("Overriding environment {}".format(id))
# /home/phu/Dropbox/general_backup/anaconda3/envs/gen_env/lib/python3.10/site-packages/gym/envs/registration.py:216: UserWarning: WARN: Overriding environment ALE/DoubleDunk-ram-v5
#   logger.warn("Overriding environment {}".format(id))
# /home/phu/Dropbox/general_backup/anaconda3/envs/gen_env/lib/python3.10/site-packages/gym/envs/registration.py:216: UserWarning: WARN: Overriding environment ALE/BasicMath-v5
#   logger.warn("Overriding environment {}".format(id))
# /home/phu/Dropbox/general_backup/anaconda3/envs/gen_env/lib/python3.10/site-packages/gym/envs/registration.py:216: UserWarning: WARN: Overriding environment ALE/BasicMath-ram-v5
#   logger.warn("Overriding environment {}".format(id))
# /home/phu/Dropbox/general_backup/anaconda3/envs/gen_env/lib/python3.10/site-packages/gym/envs/registration.py:216: UserWarning: WARN: Overriding environment ALE/Alien-v5
#   logger.warn("Overriding environment {}".format(id))
# /home/phu/Dropbox/general_backup/anaconda3/envs/gen_env/lib/python3.10/site-packages/gym/envs/registration.py:216: UserWarning: WARN: Overriding environment ALE/Alien-ram-v5
#   logger.warn("Overriding environment {}".format(id))
# /home/phu/Dropbox/general_backup/anaconda3/envs/gen_env/lib/python3.10/site-packages/gym/envs/registration.py:216: UserWarning: WARN: Overriding environment ALE/Videocube-v5
#   logger.warn("Overriding environment {}".format(id))
# /home/phu/Dropbox/general_backup/anaconda3/envs/gen_env/lib/python3.10/site-packages/gym/envs/registration.py:216: UserWarning: WARN: Overriding environment ALE/Videocube-ram-v5
#   logger.warn("Overriding environment {}".format(id))
# /home/phu/Dropbox/general_backup/anaconda3/envs/gen_env/lib/python3.10/site-packages/gym/envs/registration.py:216: UserWarning: WARN: Overriding environment ALE/SirLancelot-v5
#   logger.warn("Overriding environment {}".format(id))
# /home/phu/Dropbox/general_backup/anaconda3/envs/gen_env/lib/python3.10/site-packages/gym/envs/registration.py:216: UserWarning: WARN: Overriding environment ALE/SirLancelot-ram-v5
#   logger.warn("Overriding environment {}".format(id))
# /home/phu/Dropbox/general_backup/anaconda3/envs/gen_env/lib/python3.10/site-packages/gym/envs/registration.py:216: UserWarning: WARN: Overriding environment ALE/Hangman-v5
#   logger.warn("Overriding environment {}".format(id))
# /home/phu/Dropbox/general_backup/anaconda3/envs/gen_env/lib/python3.10/site-packages/gym/envs/registration.py:216: UserWarning: WARN: Overriding environment ALE/Hangman-ram-v5
#   logger.warn("Overriding environment {}".format(id))
# /home/phu/Dropbox/general_backup/anaconda3/envs/gen_env/lib/python3.10/site-packages/gym/envs/registration.py:216: UserWarning: WARN: Overriding environment ALE/Gravitar-v5
#   logger.warn("Overriding environment {}".format(id))
# /home/phu/Dropbox/general_backup/anaconda3/envs/gen_env/lib/python3.10/site-packages/gym/envs/registration.py:216: UserWarning: WARN: Overriding environment ALE/Gravitar-ram-v5
#   logger.warn("Overriding environment {}".format(id))
# /home/phu/Dropbox/general_backup/anaconda3/envs/gen_env/lib/python3.10/site-packages/gym/envs/registration.py:216: UserWarning: WARN: Overriding environment ALE/VideoCheckers-v5
#   logger.warn("Overriding environment {}".format(id))
# /home/phu/Dropbox/general_backup/anaconda3/envs/gen_env/lib/python3.10/site-packages/gym/envs/registration.py:216: UserWarning: WARN: Overriding environment ALE/VideoCheckers-ram-v5
#   logger.warn("Overriding environment {}".format(id))
# /home/phu/Dropbox/general_backup/anaconda3/envs/gen_env/lib/python3.10/site-packages/gym/envs/registration.py:216: UserWarning: WARN: Overriding environment ALE/AirRaid-v5
#   logger.warn("Overriding environment {}".format(id))
# /home/phu/Dropbox/general_backup/anaconda3/envs/gen_env/lib/python3.10/site-packages/gym/envs/registration.py:216: UserWarning: WARN: Overriding environment ALE/AirRaid-ram-v5
#   logger.warn("Overriding environment {}".format(id))
# /home/phu/Dropbox/general_backup/anaconda3/envs/gen_env/lib/python3.10/site-packages/gym/envs/registration.py:216: UserWarning: WARN: Overriding environment ALE/LostLuggage-v5
#   logger.warn("Overriding environment {}".format(id))
# /home/phu/Dropbox/general_backup/anaconda3/envs/gen_env/lib/python3.10/site-packages/gym/envs/registration.py:216: UserWarning: WARN: Overriding environment ALE/LostLuggage-ram-v5
#   logger.warn("Overriding environment {}".format(id))
# /home/phu/Dropbox/general_backup/anaconda3/envs/gen_env/lib/python3.10/site-packages/gym/envs/registration.py:216: UserWarning: WARN: Overriding environment ALE/DemonAttack-v5
#   logger.warn("Overriding environment {}".format(id))
# /home/phu/Dropbox/general_backup/anaconda3/envs/gen_env/lib/python3.10/site-packages/gym/envs/registration.py:216: UserWarning: WARN: Overriding environment ALE/DemonAttack-ram-v5
#   logger.warn("Overriding environment {}".format(id))
# /home/phu/Dropbox/general_backup/anaconda3/envs/gen_env/lib/python3.10/site-packages/gym/envs/registration.py:216: UserWarning: WARN: Overriding environment ALE/KeystoneKapers-v5
#   logger.warn("Overriding environment {}".format(id))
# /home/phu/Dropbox/general_backup/anaconda3/envs/gen_env/lib/python3.10/site-packages/gym/envs/registration.py:216: UserWarning: WARN: Overriding environment ALE/KeystoneKapers-ram-v5
#   logger.warn("Overriding environment {}".format(id))
# /home/phu/Dropbox/general_backup/anaconda3/envs/gen_env/lib/python3.10/site-packages/gym/envs/registration.py:216: UserWarning: WARN: Overriding environment ALE/TimePilot-v5
#   logger.warn("Overriding environment {}".format(id))
# /home/phu/Dropbox/general_backup/anaconda3/envs/gen_env/lib/python3.10/site-packages/gym/envs/registration.py:216: UserWarning: WARN: Overriding environment ALE/TimePilot-ram-v5
#   logger.warn("Overriding environment {}".format(id))
# /home/phu/Dropbox/general_backup/anaconda3/envs/gen_env/lib/python3.10/site-packages/gym/envs/registration.py:216: UserWarning: WARN: Overriding environment ALE/Entombed-v5
#   logger.warn("Overriding environment {}".format(id))
# /home/phu/Dropbox/general_backup/anaconda3/envs/gen_env/lib/python3.10/site-packages/gym/envs/registration.py:216: UserWarning: WARN: Overriding environment ALE/Entombed-ram-v5
#   logger.warn("Overriding environment {}".format(id))
# /home/phu/Dropbox/general_backup/anaconda3/envs/gen_env/lib/python3.10/site-packages/gym/envs/registration.py:216: UserWarning: WARN: Overriding environment ALE/Kangaroo-v5
#   logger.warn("Overriding environment {}".format(id))
# /home/phu/Dropbox/general_backup/anaconda3/envs/gen_env/lib/python3.10/site-packages/gym/envs/registration.py:216: UserWarning: WARN: Overriding environment ALE/Kangaroo-ram-v5
#   logger.warn("Overriding environment {}".format(id))
# /home/phu/Dropbox/general_backup/anaconda3/envs/gen_env/lib/python3.10/site-packages/gym/envs/registration.py:216: UserWarning: WARN: Overriding environment ALE/NameThisGame-v5
#   logger.warn("Overriding environment {}".format(id))
# /home/phu/Dropbox/general_backup/anaconda3/envs/gen_env/lib/python3.10/site-packages/gym/envs/registration.py:216: UserWarning: WARN: Overriding environment ALE/NameThisGame-ram-v5
#   logger.warn("Overriding environment {}".format(id))
# /home/phu/Dropbox/general_backup/anaconda3/envs/gen_env/lib/python3.10/site-packages/gym/envs/registration.py:216: UserWarning: WARN: Overriding environment ALE/FishingDerby-v5
#   logger.warn("Overriding environment {}".format(id))
# /home/phu/Dropbox/general_backup/anaconda3/envs/gen_env/lib/python3.10/site-packages/gym/envs/registration.py:216: UserWarning: WARN: Overriding environment ALE/FishingDerby-ram-v5
#   logger.warn("Overriding environment {}".format(id))
# /home/phu/Dropbox/general_backup/anaconda3/envs/gen_env/lib/python3.10/site-packages/gym/envs/registration.py:216: UserWarning: WARN: Overriding environment ALE/Venture-v5
#   logger.warn("Overriding environment {}".format(id))
# /home/phu/Dropbox/general_backup/anaconda3/envs/gen_env/lib/python3.10/site-packages/gym/envs/registration.py:216: UserWarning: WARN: Overriding environment ALE/Venture-ram-v5
#   logger.warn("Overriding environment {}".format(id))
# /home/phu/Dropbox/general_backup/anaconda3/envs/gen_env/lib/python3.10/site-packages/gym/envs/registration.py:216: UserWarning: WARN: Overriding environment ALE/Jamesbond-v5
#   logger.warn("Overriding environment {}".format(id))
# /home/phu/Dropbox/general_backup/anaconda3/envs/gen_env/lib/python3.10/site-packages/gym/envs/registration.py:216: UserWarning: WARN: Overriding environment ALE/Jamesbond-ram-v5
#   logger.warn("Overriding environment {}".format(id))
# /home/phu/Dropbox/general_backup/anaconda3/envs/gen_env/lib/python3.10/site-packages/gym/envs/registration.py:216: UserWarning: WARN: Overriding environment ALE/Skiing-v5
#   logger.warn("Overriding environment {}".format(id))
# /home/phu/Dropbox/general_backup/anaconda3/envs/gen_env/lib/python3.10/site-packages/gym/envs/registration.py:216: UserWarning: WARN: Overriding environment ALE/Skiing-ram-v5
#   logger.warn("Overriding environment {}".format(id))
# /home/phu/Dropbox/general_backup/anaconda3/envs/gen_env/lib/python3.10/site-packages/gym/envs/registration.py:216: UserWarning: WARN: Overriding environment ALE/Casino-v5
#   logger.warn("Overriding environment {}".format(id))
# /home/phu/Dropbox/general_backup/anaconda3/envs/gen_env/lib/python3.10/site-packages/gym/envs/registration.py:216: UserWarning: WARN: Overriding environment ALE/Casino-ram-v5
#   logger.warn("Overriding environment {}".format(id))
# /home/phu/Dropbox/general_backup/anaconda3/envs/gen_env/lib/python3.10/site-packages/gym/envs/registration.py:216: UserWarning: WARN: Overriding environment ALE/Zaxxon-v5
#   logger.warn("Overriding environment {}".format(id))
# /home/phu/Dropbox/general_backup/anaconda3/envs/gen_env/lib/python3.10/site-packages/gym/envs/registration.py:216: UserWarning: WARN: Overriding environment ALE/Zaxxon-ram-v5
#   logger.warn("Overriding environment {}".format(id))
# /home/phu/Dropbox/general_backup/anaconda3/envs/gen_env/lib/python3.10/site-packages/gym/envs/registration.py:216: UserWarning: WARN: Overriding environment ALE/Seaquest-v5
#   logger.warn("Overriding environment {}".format(id))
# /home/phu/Dropbox/general_backup/anaconda3/envs/gen_env/lib/python3.10/site-packages/gym/envs/registration.py:216: UserWarning: WARN: Overriding environment ALE/Seaquest-ram-v5
#   logger.warn("Overriding environment {}".format(id))
# /home/phu/Dropbox/general_backup/anaconda3/envs/gen_env/lib/python3.10/site-packages/gym/envs/registration.py:216: UserWarning: WARN: Overriding environment ALE/BeamRider-v5
#   logger.warn("Overriding environment {}".format(id))
# /home/phu/Dropbox/general_backup/anaconda3/envs/gen_env/lib/python3.10/site-packages/gym/envs/registration.py:216: UserWarning: WARN: Overriding environment ALE/BeamRider-ram-v5
#   logger.warn("Overriding environment {}".format(id))
# /home/phu/Dropbox/general_backup/anaconda3/envs/gen_env/lib/python3.10/site-packages/gym/envs/registration.py:216: UserWarning: WARN: Overriding environment ALE/Berzerk-v5
#   logger.warn("Overriding environment {}".format(id))
# /home/phu/Dropbox/general_backup/anaconda3/envs/gen_env/lib/python3.10/site-packages/gym/envs/registration.py:216: UserWarning: WARN: Overriding environment ALE/Berzerk-ram-v5
#   logger.warn("Overriding environment {}".format(id))
# /home/phu/Dropbox/general_backup/anaconda3/envs/gen_env/lib/python3.10/site-packages/gym/envs/registration.py:216: UserWarning: WARN: Overriding environment ALE/ChopperCommand-v5
#   logger.warn("Overriding environment {}".format(id))
# /home/phu/Dropbox/general_backup/anaconda3/envs/gen_env/lib/python3.10/site-packages/gym/envs/registration.py:216: UserWarning: WARN: Overriding environment ALE/ChopperCommand-ram-v5
#   logger.warn("Overriding environment {}".format(id))
# /home/phu/Dropbox/general_backup/anaconda3/envs/gen_env/lib/python3.10/site-packages/gym/envs/registration.py:216: UserWarning: WARN: Overriding environment ALE/Centipede-v5
#   logger.warn("Overriding environment {}".format(id))
# /home/phu/Dropbox/general_backup/anaconda3/envs/gen_env/lib/python3.10/site-packages/gym/envs/registration.py:216: UserWarning: WARN: Overriding environment ALE/Centipede-ram-v5
#   logger.warn("Overriding environment {}".format(id))
# /home/phu/Dropbox/general_backup/anaconda3/envs/gen_env/lib/python3.10/site-packages/gym/envs/registration.py:216: UserWarning: WARN: Overriding environment ALE/Hero-v5
#   logger.warn("Overriding environment {}".format(id))
# /home/phu/Dropbox/general_backup/anaconda3/envs/gen_env/lib/python3.10/site-packages/gym/envs/registration.py:216: UserWarning: WARN: Overriding environment ALE/Hero-ram-v5
#   logger.warn("Overriding environment {}".format(id))
# /home/phu/Dropbox/general_backup/anaconda3/envs/gen_env/lib/python3.10/site-packages/gym/envs/registration.py:216: UserWarning: WARN: Overriding environment ALE/UpNDown-v5
#   logger.warn("Overriding environment {}".format(id))
# /home/phu/Dropbox/general_backup/anaconda3/envs/gen_env/lib/python3.10/site-packages/gym/envs/registration.py:216: UserWarning: WARN: Overriding environment ALE/UpNDown-ram-v5
#   logger.warn("Overriding environment {}".format(id))
# /home/phu/Dropbox/general_backup/anaconda3/envs/gen_env/lib/python3.10/site-packages/gym/envs/registration.py:216: UserWarning: WARN: Overriding environment ALE/DonkeyKong-v5
#   logger.warn("Overriding environment {}".format(id))
# /home/phu/Dropbox/general_backup/anaconda3/envs/gen_env/lib/python3.10/site-packages/gym/envs/registration.py:216: UserWarning: WARN: Overriding environment ALE/DonkeyKong-ram-v5
#   logger.warn("Overriding environment {}".format(id))
# /home/phu/Dropbox/general_backup/anaconda3/envs/gen_env/lib/python3.10/site-packages/gym/envs/registration.py:216: UserWarning: WARN: Overriding environment ALE/Earthworld-v5
#   logger.warn("Overriding environment {}".format(id))
# /home/phu/Dropbox/general_backup/anaconda3/envs/gen_env/lib/python3.10/site-packages/gym/envs/registration.py:216: UserWarning: WARN: Overriding environment ALE/Earthworld-ram-v5
#   logger.warn("Overriding environment {}".format(id))
# /home/phu/Dropbox/general_backup/anaconda3/envs/gen_env/lib/python3.10/site-packages/gym/envs/registration.py:216: UserWarning: WARN: Overriding environment ALE/Darkchambers-v5
#   logger.warn("Overriding environment {}".format(id))
# /home/phu/Dropbox/general_backup/anaconda3/envs/gen_env/lib/python3.10/site-packages/gym/envs/registration.py:216: UserWarning: WARN: Overriding environment ALE/Darkchambers-ram-v5
#   logger.warn("Overriding environment {}".format(id))
# /home/phu/Dropbox/general_backup/anaconda3/envs/gen_env/lib/python3.10/site-packages/gym/envs/registration.py:216: UserWarning: WARN: Overriding environment ALE/Frogger-v5
#   logger.warn("Overriding environment {}".format(id))
# /home/phu/Dropbox/general_backup/anaconda3/envs/gen_env/lib/python3.10/site-packages/gym/envs/registration.py:216: UserWarning: WARN: Overriding environment ALE/Frogger-ram-v5
#   logger.warn("Overriding environment {}".format(id))
# /home/phu/Dropbox/general_backup/anaconda3/envs/gen_env/lib/python3.10/site-packages/gym/envs/registration.py:216: UserWarning: WARN: Overriding environment ALE/SpaceInvaders-v5
#   logger.warn("Overriding environment {}".format(id))
# /home/phu/Dropbox/general_backup/anaconda3/envs/gen_env/lib/python3.10/site-packages/gym/envs/registration.py:216: UserWarning: WARN: Overriding environment ALE/SpaceInvaders-ram-v5
#   logger.warn("Overriding environment {}".format(id))
# /home/phu/Dropbox/general_backup/anaconda3/envs/gen_env/lib/python3.10/site-packages/gym/envs/registration.py:216: UserWarning: WARN: Overriding environment ALE/Trondead-v5
#   logger.warn("Overriding environment {}".format(id))
# /home/phu/Dropbox/general_backup/anaconda3/envs/gen_env/lib/python3.10/site-packages/gym/envs/registration.py:216: UserWarning: WARN: Overriding environment ALE/Trondead-ram-v5
#   logger.warn("Overriding environment {}".format(id))
# /home/phu/Dropbox/general_backup/anaconda3/envs/gen_env/lib/python3.10/site-packages/gym/envs/registration.py:216: UserWarning: WARN: Overriding environment ALE/KungFuMaster-v5
#   logger.warn("Overriding environment {}".format(id))
# /home/phu/Dropbox/general_backup/anaconda3/envs/gen_env/lib/python3.10/site-packages/gym/envs/registration.py:216: UserWarning: WARN: Overriding environment ALE/KungFuMaster-ram-v5
#   logger.warn("Overriding environment {}".format(id))
# /home/phu/Dropbox/general_backup/anaconda3/envs/gen_env/lib/python3.10/site-packages/gym/envs/registration.py:216: UserWarning: WARN: Overriding environment ALE/PrivateEye-v5
#   logger.warn("Overriding environment {}".format(id))
# /home/phu/Dropbox/general_backup/anaconda3/envs/gen_env/lib/python3.10/site-packages/gym/envs/registration.py:216: UserWarning: WARN: Overriding environment ALE/PrivateEye-ram-v5
#   logger.warn("Overriding environment {}".format(id))
# /home/phu/Dropbox/general_backup/anaconda3/envs/gen_env/lib/python3.10/site-packages/gym/envs/registration.py:216: UserWarning: WARN: Overriding environment ALE/SpaceWar-v5
#   logger.warn("Overriding environment {}".format(id))
# /home/phu/Dropbox/general_backup/anaconda3/envs/gen_env/lib/python3.10/site-packages/gym/envs/registration.py:216: UserWarning: WARN: Overriding environment ALE/SpaceWar-ram-v5
#   logger.warn("Overriding environment {}".format(id))
# /home/phu/Dropbox/general_backup/anaconda3/envs/gen_env/lib/python3.10/site-packages/gym/envs/registration.py:216: UserWarning: WARN: Overriding environment ALE/KingKong-v5
#   logger.warn("Overriding environment {}".format(id))
# /home/phu/Dropbox/general_backup/anaconda3/envs/gen_env/lib/python3.10/site-packages/gym/envs/registration.py:216: UserWarning: WARN: Overriding environment ALE/KingKong-ram-v5
#   logger.warn("Overriding environment {}".format(id))
# /home/phu/Dropbox/general_backup/anaconda3/envs/gen_env/lib/python3.10/site-packages/gym/envs/registration.py:216: UserWarning: WARN: Overriding environment ALE/Breakout-v5
#   logger.warn("Overriding environment {}".format(id))
# /home/phu/Dropbox/general_backup/anaconda3/envs/gen_env/lib/python3.10/site-packages/gym/envs/registration.py:216: UserWarning: WARN: Overriding environment ALE/Breakout-ram-v5
#   logger.warn("Overriding environment {}".format(id))
# /home/phu/Dropbox/general_backup/anaconda3/envs/gen_env/lib/python3.10/site-packages/gym/envs/registration.py:216: UserWarning: WARN: Overriding environment ALE/Solaris-v5
#   logger.warn("Overriding environment {}".format(id))
# /home/phu/Dropbox/general_backup/anaconda3/envs/gen_env/lib/python3.10/site-packages/gym/envs/registration.py:216: UserWarning: WARN: Overriding environment ALE/Solaris-ram-v5
#   logger.warn("Overriding environment {}".format(id))
# /home/phu/Dropbox/general_backup/anaconda3/envs/gen_env/lib/python3.10/site-packages/gym/envs/registration.py:216: UserWarning: WARN: Overriding environment ALE/Phoenix-v5
#   logger.warn("Overriding environment {}".format(id))
# /home/phu/Dropbox/general_backup/anaconda3/envs/gen_env/lib/python3.10/site-packages/gym/envs/registration.py:216: UserWarning: WARN: Overriding environment ALE/Phoenix-ram-v5
#   logger.warn("Overriding environment {}".format(id))
# /home/phu/Dropbox/general_backup/anaconda3/envs/gen_env/lib/python3.10/site-packages/gym/envs/registration.py:216: UserWarning: WARN: Overriding environment ALE/WordZapper-v5
#   logger.warn("Overriding environment {}".format(id))
# /home/phu/Dropbox/general_backup/anaconda3/envs/gen_env/lib/python3.10/site-packages/gym/envs/registration.py:216: UserWarning: WARN: Overriding environment ALE/WordZapper-ram-v5
#   logger.warn("Overriding environment {}".format(id))
# /home/phu/Dropbox/general_backup/anaconda3/envs/gen_env/lib/python3.10/site-packages/gym/envs/registration.py:216: UserWarning: WARN: Overriding environment ALE/Riverraid-v5
#   logger.warn("Overriding environment {}".format(id))
# /home/phu/Dropbox/general_backup/anaconda3/envs/gen_env/lib/python3.10/site-packages/gym/envs/registration.py:216: UserWarning: WARN: Overriding environment ALE/Riverraid-ram-v5
#   logger.warn("Overriding environment {}".format(id))
# /home/phu/Dropbox/general_backup/anaconda3/envs/gen_env/lib/python3.10/site-packages/gym/envs/registration.py:216: UserWarning: WARN: Overriding environment ALE/Surround-v5
#   logger.warn("Overriding environment {}".format(id))
# /home/phu/Dropbox/general_backup/anaconda3/envs/gen_env/lib/python3.10/site-packages/gym/envs/registration.py:216: UserWarning: WARN: Overriding environment ALE/Surround-ram-v5
#   logger.warn("Overriding environment {}".format(id))
# /home/phu/Dropbox/general_backup/anaconda3/envs/gen_env/lib/python3.10/site-packages/gym/envs/registration.py:216: UserWarning: WARN: Overriding environment ALE/Defender-v5
#   logger.warn("Overriding environment {}".format(id))
# /home/phu/Dropbox/general_backup/anaconda3/envs/gen_env/lib/python3.10/site-packages/gym/envs/registration.py:216: UserWarning: WARN: Overriding environment ALE/Defender-ram-v5
#   logger.warn("Overriding environment {}".format(id))
# /home/phu/Dropbox/general_backup/anaconda3/envs/gen_env/lib/python3.10/site-packages/gym/envs/registration.py:216: UserWarning: WARN: Overriding environment ALE/FlagCapture-v5
#   logger.warn("Overriding environment {}".format(id))
# /home/phu/Dropbox/general_backup/anaconda3/envs/gen_env/lib/python3.10/site-packages/gym/envs/registration.py:216: UserWarning: WARN: Overriding environment ALE/FlagCapture-ram-v5
#   logger.warn("Overriding environment {}".format(id))
# /home/phu/Dropbox/general_backup/anaconda3/envs/gen_env/lib/python3.10/site-packages/gym/envs/registration.py:216: UserWarning: WARN: Overriding environment ALE/Boxing-v5
#   logger.warn("Overriding environment {}".format(id))
# /home/phu/Dropbox/general_backup/anaconda3/envs/gen_env/lib/python3.10/site-packages/gym/envs/registration.py:216: UserWarning: WARN: Overriding environment ALE/Boxing-ram-v5
#   logger.warn("Overriding environment {}".format(id))
# /home/phu/Dropbox/general_backup/anaconda3/envs/gen_env/lib/python3.10/site-packages/gym/envs/registration.py:216: UserWarning: WARN: Overriding environment ALE/Crossbow-v5
#   logger.warn("Overriding environment {}".format(id))
# /home/phu/Dropbox/general_backup/anaconda3/envs/gen_env/lib/python3.10/site-packages/gym/envs/registration.py:216: UserWarning: WARN: Overriding environment ALE/Crossbow-ram-v5
#   logger.warn("Overriding environment {}".format(id))
# /home/phu/Dropbox/general_backup/anaconda3/envs/gen_env/lib/python3.10/site-packages/gym/envs/registration.py:216: UserWarning: WARN: Overriding environment ALE/VideoPinball-v5
#   logger.warn("Overriding environment {}".format(id))
# /home/phu/Dropbox/general_backup/anaconda3/envs/gen_env/lib/python3.10/site-packages/gym/envs/registration.py:216: UserWarning: WARN: Overriding environment ALE/VideoPinball-ram-v5
#   logger.warn("Overriding environment {}".format(id))
# /home/phu/Dropbox/general_backup/anaconda3/envs/gen_env/lib/python3.10/site-packages/gym/envs/registration.py:216: UserWarning: WARN: Overriding environment ALE/MarioBros-v5
#   logger.warn("Overriding environment {}".format(id))
# /home/phu/Dropbox/general_backup/anaconda3/envs/gen_env/lib/python3.10/site-packages/gym/envs/registration.py:216: UserWarning: WARN: Overriding environment ALE/MarioBros-ram-v5
#   logger.warn("Overriding environment {}".format(id))
# /home/phu/Dropbox/general_backup/anaconda3/envs/gen_env/lib/python3.10/site-packages/gym/envs/registration.py:216: UserWarning: WARN: Overriding environment ALE/HumanCannonball-v5
#   logger.warn("Overriding environment {}".format(id))
# /home/phu/Dropbox/general_backup/anaconda3/envs/gen_env/lib/python3.10/site-packages/gym/envs/registration.py:216: UserWarning: WARN: Overriding environment ALE/HumanCannonball-ram-v5
#   logger.warn("Overriding environment {}".format(id))
# /home/phu/Dropbox/general_backup/anaconda3/envs/gen_env/lib/python3.10/site-packages/gym/envs/registration.py:216: UserWarning: WARN: Overriding environment ALE/StarGunner-v5
#   logger.warn("Overriding environment {}".format(id))
# /home/phu/Dropbox/general_backup/anaconda3/envs/gen_env/lib/python3.10/site-packages/gym/envs/registration.py:216: UserWarning: WARN: Overriding environment ALE/StarGunner-ram-v5
#   logger.warn("Overriding environment {}".format(id))
# /home/phu/Dropbox/general_backup/anaconda3/envs/gen_env/lib/python3.10/site-packages/gym/envs/registration.py:216: UserWarning: WARN: Overriding environment ALE/Blackjack-v5
#   logger.warn("Overriding environment {}".format(id))
# /home/phu/Dropbox/general_backup/anaconda3/envs/gen_env/lib/python3.10/site-packages/gym/envs/registration.py:216: UserWarning: WARN: Overriding environment ALE/Blackjack-ram-v5
#   logger.warn("Overriding environment {}".format(id))
# /home/phu/Dropbox/general_backup/anaconda3/envs/gen_env/lib/python3.10/site-packages/gym/envs/registration.py:216: UserWarning: WARN: Overriding environment ALE/Krull-v5
#   logger.warn("Overriding environment {}".format(id))
# /home/phu/Dropbox/general_backup/anaconda3/envs/gen_env/lib/python3.10/site-packages/gym/envs/registration.py:216: UserWarning: WARN: Overriding environment ALE/Krull-ram-v5
#   logger.warn("Overriding environment {}".format(id))
# /home/phu/Dropbox/general_backup/anaconda3/envs/gen_env/lib/python3.10/site-packages/gym/envs/registration.py:216: UserWarning: WARN: Overriding environment ALE/Backgammon-v5
#   logger.warn("Overriding environment {}".format(id))
# /home/phu/Dropbox/general_backup/anaconda3/envs/gen_env/lib/python3.10/site-packages/gym/envs/registration.py:216: UserWarning: WARN: Overriding environment ALE/Backgammon-ram-v5
#   logger.warn("Overriding environment {}".format(id))
# /home/phu/Dropbox/general_backup/anaconda3/envs/gen_env/lib/python3.10/site-packages/gym/envs/registration.py:216: UserWarning: WARN: Overriding environment ALE/Superman-v5
#   logger.warn("Overriding environment {}".format(id))
# /home/phu/Dropbox/general_backup/anaconda3/envs/gen_env/lib/python3.10/site-packages/gym/envs/registration.py:216: UserWarning: WARN: Overriding environment ALE/Superman-ram-v5
#   logger.warn("Overriding environment {}".format(id))
# /home/phu/Dropbox/general_backup/anaconda3/envs/gen_env/lib/python3.10/site-packages/gym/envs/registration.py:216: UserWarning: WARN: Overriding environment ALE/MiniatureGolf-v5
#   logger.warn("Overriding environment {}".format(id))
# /home/phu/Dropbox/general_backup/anaconda3/envs/gen_env/lib/python3.10/site-packages/gym/envs/registration.py:216: UserWarning: WARN: Overriding environment ALE/MiniatureGolf-ram-v5
#   logger.warn("Overriding environment {}".format(id))
# /home/phu/Dropbox/general_backup/anaconda3/envs/gen_env/lib/python3.10/site-packages/gym/envs/registration.py:216: UserWarning: WARN: Overriding environment ALE/Et-v5
#   logger.warn("Overriding environment {}".format(id))
# /home/phu/Dropbox/general_backup/anaconda3/envs/gen_env/lib/python3.10/site-packages/gym/envs/registration.py:216: UserWarning: WARN: Overriding environment ALE/Et-ram-v5
#   logger.warn("Overriding environment {}".format(id))
# /home/phu/Dropbox/general_backup/anaconda3/envs/gen_env/lib/python3.10/site-packages/gym/envs/registration.py:216: UserWarning: WARN: Overriding environment ALE/Pong-v5
#   logger.warn("Overriding environment {}".format(id))
# /home/phu/Dropbox/general_backup/anaconda3/envs/gen_env/lib/python3.10/site-packages/gym/envs/registration.py:216: UserWarning: WARN: Overriding environment ALE/Pong-ram-v5
#   logger.warn("Overriding environment {}".format(id))
# /home/phu/Dropbox/general_backup/anaconda3/envs/gen_env/lib/python3.10/site-packages/gym/envs/registration.py:216: UserWarning: WARN: Overriding environment ALE/IceHockey-v5
#   logger.warn("Overriding environment {}".format(id))
# /home/phu/Dropbox/general_backup/anaconda3/envs/gen_env/lib/python3.10/site-packages/gym/envs/registration.py:216: UserWarning: WARN: Overriding environment ALE/IceHockey-ram-v5
#   logger.warn("Overriding environment {}".format(id))
# /home/phu/Dropbox/general_backup/anaconda3/envs/gen_env/lib/python3.10/site-packages/gym/envs/registration.py:216: UserWarning: WARN: Overriding environment Adventure-v0
#   logger.warn("Overriding environment {}".format(id))
# ...
#   logger.warn("Overriding environment {}".format(id))
# /home/phu/Dropbox/general_backup/anaconda3/envs/gen_env/lib/python3.10/site-packages/gym/envs/registration.py:216: UserWarning: WARN: Overriding environment UpNDownDeterministic-v4
#   logger.warn("Overriding environment {}".format(id))
# /home/phu/Dropbox/general_backup/anaconda3/envs/gen_env/lib/python3.10/site-packages/gym/envs/registration.py:216: UserWarning: WARN: Overriding environment UpNDownNoFrameskip-v4
#   logger.warn("Overriding environment {}".format(id))
# /home/phu/Dropbox/general_backup/anaconda3/envs/gen_env/lib/python3.10/site-packages/gym/envs/registration.py:216: UserWarning: WARN: Overriding environment UpNDown-ram-v0
#   logger.warn("Overriding environment {}".format(id))
# /home/phu/Dropbox/general_backup/anaconda3/envs/gen_env/lib/python3.10/site-packages/gym/envs/registration.py:216: UserWarning: WARN: Overriding environment UpNDown-ramDeterministic-v0
#   logger.warn("Overriding environment {}".format(id))
# /home/phu/Dropbox/general_backup/anaconda3/envs/gen_env/lib/python3.10/site-packages/gym/envs/registration.py:216: UserWarning: WARN: Overriding environment UpNDown-ramNoFrameskip-v0
#   logger.warn("Overriding environment {}".format(id))
# /home/phu/Dropbox/general_backup/anaconda3/envs/gen_env/lib/python3.10/site-packages/gym/envs/registration.py:216: UserWarning: WARN: Overriding environment UpNDown-ram-v4
#   logger.warn("Overriding environment {}".format(id))
# /home/phu/Dropbox/general_backup/anaconda3/envs/gen_env/lib/python3.10/site-packages/gym/envs/registration.py:216: UserWarning: WARN: Overriding environment UpNDown-ramDeterministic-v4
#   logger.warn("Overriding environment {}".format(id))
# /home/phu/Dropbox/general_backup/anaconda3/envs/gen_env/lib/python3.10/site-packages/gym/envs/registration.py:216: UserWarning: WARN: Overriding environment UpNDown-ramNoFrameskip-v4
#   logger.warn("Overriding environment {}".format(id))
# /home/phu/Dropbox/general_backup/anaconda3/envs/gen_env/lib/python3.10/site-packages/gym/envs/registration.py:216: UserWarning: WARN: Overriding environment Venture-v0
#   logger.warn("Overriding environment {}".format(id))
# /home/phu/Dropbox/general_backup/anaconda3/envs/gen_env/lib/python3.10/site-packages/gym/envs/registration.py:216: UserWarning: WARN: Overriding environment VentureDeterministic-v0
#   logger.warn("Overriding environment {}".format(id))
# /home/phu/Dropbox/general_backup/anaconda3/envs/gen_env/lib/python3.10/site-packages/gym/envs/registration.py:216: UserWarning: WARN: Overriding environment VentureNoFrameskip-v0
#   logger.warn("Overriding environment {}".format(id))
# /home/phu/Dropbox/general_backup/anaconda3/envs/gen_env/lib/python3.10/site-packages/gym/envs/registration.py:216: UserWarning: WARN: Overriding environment Venture-v4
#   logger.warn("Overriding environment {}".format(id))
# /home/phu/Dropbox/general_backup/anaconda3/envs/gen_env/lib/python3.10/site-packages/gym/envs/registration.py:216: UserWarning: WARN: Overriding environment VentureDeterministic-v4
#   logger.warn("Overriding environment {}".format(id))
# /home/phu/Dropbox/general_backup/anaconda3/envs/gen_env/lib/python3.10/site-packages/gym/envs/registration.py:216: UserWarning: WARN: Overriding environment VentureNoFrameskip-v4
#   logger.warn("Overriding environment {}".format(id))
# /home/phu/Dropbox/general_backup/anaconda3/envs/gen_env/lib/python3.10/site-packages/gym/envs/registration.py:216: UserWarning: WARN: Overriding environment Venture-ram-v0
#   logger.warn("Overriding environment {}".format(id))
# /home/phu/Dropbox/general_backup/anaconda3/envs/gen_env/lib/python3.10/site-packages/gym/envs/registration.py:216: UserWarning: WARN: Overriding environment Venture-ramDeterministic-v0
#   logger.warn("Overriding environment {}".format(id))
# /home/phu/Dropbox/general_backup/anaconda3/envs/gen_env/lib/python3.10/site-packages/gym/envs/registration.py:216: UserWarning: WARN: Overriding environment Venture-ramNoFrameskip-v0
#   logger.warn("Overriding environment {}".format(id))
# /home/phu/Dropbox/general_backup/anaconda3/envs/gen_env/lib/python3.10/site-packages/gym/envs/registration.py:216: UserWarning: WARN: Overriding environment Venture-ram-v4
#   logger.warn("Overriding environment {}".format(id))
# /home/phu/Dropbox/general_backup/anaconda3/envs/gen_env/lib/python3.10/site-packages/gym/envs/registration.py:216: UserWarning: WARN: Overriding environment Venture-ramDeterministic-v4
#   logger.warn("Overriding environment {}".format(id))
# /home/phu/Dropbox/general_backup/anaconda3/envs/gen_env/lib/python3.10/site-packages/gym/envs/registration.py:216: UserWarning: WARN: Overriding environment Venture-ramNoFrameskip-v4
#   logger.warn("Overriding environment {}".format(id))
# /home/phu/Dropbox/general_backup/anaconda3/envs/gen_env/lib/python3.10/site-packages/gym/envs/registration.py:216: UserWarning: WARN: Overriding environment VideoPinball-v0
#   logger.warn("Overriding environment {}".format(id))
# /home/phu/Dropbox/general_backup/anaconda3/envs/gen_env/lib/python3.10/site-packages/gym/envs/registration.py:216: UserWarning: WARN: Overriding environment VideoPinballDeterministic-v0
#   logger.warn("Overriding environment {}".format(id))
# /home/phu/Dropbox/general_backup/anaconda3/envs/gen_env/lib/python3.10/site-packages/gym/envs/registration.py:216: UserWarning: WARN: Overriding environment VideoPinballNoFrameskip-v0
#   logger.warn("Overriding environment {}".format(id))
# /home/phu/Dropbox/general_backup/anaconda3/envs/gen_env/lib/python3.10/site-packages/gym/envs/registration.py:216: UserWarning: WARN: Overriding environment VideoPinball-v4
#   logger.warn("Overriding environment {}".format(id))
# /home/phu/Dropbox/general_backup/anaconda3/envs/gen_env/lib/python3.10/site-packages/gym/envs/registration.py:216: UserWarning: WARN: Overriding environment VideoPinballDeterministic-v4
#   logger.warn("Overriding environment {}".format(id))
# /home/phu/Dropbox/general_backup/anaconda3/envs/gen_env/lib/python3.10/site-packages/gym/envs/registration.py:216: UserWarning: WARN: Overriding environment VideoPinballNoFrameskip-v4
#   logger.warn("Overriding environment {}".format(id))
# /home/phu/Dropbox/general_backup/anaconda3/envs/gen_env/lib/python3.10/site-packages/gym/envs/registration.py:216: UserWarning: WARN: Overriding environment VideoPinball-ram-v0
#   logger.warn("Overriding environment {}".format(id))
# /home/phu/Dropbox/general_backup/anaconda3/envs/gen_env/lib/python3.10/site-packages/gym/envs/registration.py:216: UserWarning: WARN: Overriding environment VideoPinball-ramDeterministic-v0
#   logger.warn("Overriding environment {}".format(id))
# /home/phu/Dropbox/general_backup/anaconda3/envs/gen_env/lib/python3.10/site-packages/gym/envs/registration.py:216: UserWarning: WARN: Overriding environment VideoPinball-ramNoFrameskip-v0
#   logger.warn("Overriding environment {}".format(id))
# /home/phu/Dropbox/general_backup/anaconda3/envs/gen_env/lib/python3.10/site-packages/gym/envs/registration.py:216: UserWarning: WARN: Overriding environment VideoPinball-ram-v4
#   logger.warn("Overriding environment {}".format(id))
# /home/phu/Dropbox/general_backup/anaconda3/envs/gen_env/lib/python3.10/site-packages/gym/envs/registration.py:216: UserWarning: WARN: Overriding environment VideoPinball-ramDeterministic-v4
#   logger.warn("Overriding environment {}".format(id))
# /home/phu/Dropbox/general_backup/anaconda3/envs/gen_env/lib/python3.10/site-packages/gym/envs/registration.py:216: UserWarning: WARN: Overriding environment VideoPinball-ramNoFrameskip-v4
#   logger.warn("Overriding environment {}".format(id))
# /home/phu/Dropbox/general_backup/anaconda3/envs/gen_env/lib/python3.10/site-packages/gym/envs/registration.py:216: UserWarning: WARN: Overriding environment WizardOfWor-v0
#   logger.warn("Overriding environment {}".format(id))
# /home/phu/Dropbox/general_backup/anaconda3/envs/gen_env/lib/python3.10/site-packages/gym/envs/registration.py:216: UserWarning: WARN: Overriding environment WizardOfWorDeterministic-v0
#   logger.warn("Overriding environment {}".format(id))
# /home/phu/Dropbox/general_backup/anaconda3/envs/gen_env/lib/python3.10/site-packages/gym/envs/registration.py:216: UserWarning: WARN: Overriding environment WizardOfWorNoFrameskip-v0
#   logger.warn("Overriding environment {}".format(id))
# /home/phu/Dropbox/general_backup/anaconda3/envs/gen_env/lib/python3.10/site-packages/gym/envs/registration.py:216: UserWarning: WARN: Overriding environment WizardOfWor-v4
#   logger.warn("Overriding environment {}".format(id))
# /home/phu/Dropbox/general_backup/anaconda3/envs/gen_env/lib/python3.10/site-packages/gym/envs/registration.py:216: UserWarning: WARN: Overriding environment WizardOfWorDeterministic-v4
#   logger.warn("Overriding environment {}".format(id))
# /home/phu/Dropbox/general_backup/anaconda3/envs/gen_env/lib/python3.10/site-packages/gym/envs/registration.py:216: UserWarning: WARN: Overriding environment WizardOfWorNoFrameskip-v4
#   logger.warn("Overriding environment {}".format(id))
# /home/phu/Dropbox/general_backup/anaconda3/envs/gen_env/lib/python3.10/site-packages/gym/envs/registration.py:216: UserWarning: WARN: Overriding environment WizardOfWor-ram-v0
#   logger.warn("Overriding environment {}".format(id))
# /home/phu/Dropbox/general_backup/anaconda3/envs/gen_env/lib/python3.10/site-packages/gym/envs/registration.py:216: UserWarning: WARN: Overriding environment WizardOfWor-ramDeterministic-v0
#   logger.warn("Overriding environment {}".format(id))
# /home/phu/Dropbox/general_backup/anaconda3/envs/gen_env/lib/python3.10/site-packages/gym/envs/registration.py:216: UserWarning: WARN: Overriding environment WizardOfWor-ramNoFrameskip-v0
#   logger.warn("Overriding environment {}".format(id))
# /home/phu/Dropbox/general_backup/anaconda3/envs/gen_env/lib/python3.10/site-packages/gym/envs/registration.py:216: UserWarning: WARN: Overriding environment WizardOfWor-ram-v4
#   logger.warn("Overriding environment {}".format(id))
# /home/phu/Dropbox/general_backup/anaconda3/envs/gen_env/lib/python3.10/site-packages/gym/envs/registration.py:216: UserWarning: WARN: Overriding environment WizardOfWor-ramDeterministic-v4
#   logger.warn("Overriding environment {}".format(id))
# /home/phu/Dropbox/general_backup/anaconda3/envs/gen_env/lib/python3.10/site-packages/gym/envs/registration.py:216: UserWarning: WARN: Overriding environment WizardOfWor-ramNoFrameskip-v4
#   logger.warn("Overriding environment {}".format(id))
# /home/phu/Dropbox/general_backup/anaconda3/envs/gen_env/lib/python3.10/site-packages/gym/envs/registration.py:216: UserWarning: WARN: Overriding environment YarsRevenge-v0
#   logger.warn("Overriding environment {}".format(id))
# /home/phu/Dropbox/general_backup/anaconda3/envs/gen_env/lib/python3.10/site-packages/gym/envs/registration.py:216: UserWarning: WARN: Overriding environment YarsRevengeDeterministic-v0
#   logger.warn("Overriding environment {}".format(id))
# /home/phu/Dropbox/general_backup/anaconda3/envs/gen_env/lib/python3.10/site-packages/gym/envs/registration.py:216: UserWarning: WARN: Overriding environment YarsRevengeNoFrameskip-v0
#   logger.warn("Overriding environment {}".format(id))
# /home/phu/Dropbox/general_backup/anaconda3/envs/gen_env/lib/python3.10/site-packages/gym/envs/registration.py:216: UserWarning: WARN: Overriding environment YarsRevenge-v4
#   logger.warn("Overriding environment {}".format(id))
# /home/phu/Dropbox/general_backup/anaconda3/envs/gen_env/lib/python3.10/site-packages/gym/envs/registration.py:216: UserWarning: WARN: Overriding environment YarsRevengeDeterministic-v4
#   logger.warn("Overriding environment {}".format(id))
# /home/phu/Dropbox/general_backup/anaconda3/envs/gen_env/lib/python3.10/site-packages/gym/envs/registration.py:216: UserWarning: WARN: Overriding environment YarsRevengeNoFrameskip-v4
#   logger.warn("Overriding environment {}".format(id))
# /home/phu/Dropbox/general_backup/anaconda3/envs/gen_env/lib/python3.10/site-packages/gym/envs/registration.py:216: UserWarning: WARN: Overriding environment YarsRevenge-ram-v0
#   logger.warn("Overriding environment {}".format(id))
# /home/phu/Dropbox/general_backup/anaconda3/envs/gen_env/lib/python3.10/site-packages/gym/envs/registration.py:216: UserWarning: WARN: Overriding environment YarsRevenge-ramDeterministic-v0
#   logger.warn("Overriding environment {}".format(id))
# /home/phu/Dropbox/general_backup/anaconda3/envs/gen_env/lib/python3.10/site-packages/gym/envs/registration.py:216: UserWarning: WARN: Overriding environment YarsRevenge-ramNoFrameskip-v0
#   logger.warn("Overriding environment {}".format(id))
# /home/phu/Dropbox/general_backup/anaconda3/envs/gen_env/lib/python3.10/site-packages/gym/envs/registration.py:216: UserWarning: WARN: Overriding environment YarsRevenge-ram-v4
#   logger.warn("Overriding environment {}".format(id))
# /home/phu/Dropbox/general_backup/anaconda3/envs/gen_env/lib/python3.10/site-packages/gym/envs/registration.py:216: UserWarning: WARN: Overriding environment YarsRevenge-ramDeterministic-v4
#   logger.warn("Overriding environment {}".format(id))
# /home/phu/Dropbox/general_backup/anaconda3/envs/gen_env/lib/python3.10/site-packages/gym/envs/registration.py:216: UserWarning: WARN: Overriding environment YarsRevenge-ramNoFrameskip-v4
#   logger.warn("Overriding environment {}".format(id))
# /home/phu/Dropbox/general_backup/anaconda3/envs/gen_env/lib/python3.10/site-packages/gym/envs/registration.py:216: UserWarning: WARN: Overriding environment Zaxxon-v0
#   logger.warn("Overriding environment {}".format(id))
# /home/phu/Dropbox/general_backup/anaconda3/envs/gen_env/lib/python3.10/site-packages/gym/envs/registration.py:216: UserWarning: WARN: Overriding environment ZaxxonDeterministic-v0
#   logger.warn("Overriding environment {}".format(id))
# /home/phu/Dropbox/general_backup/anaconda3/envs/gen_env/lib/python3.10/site-packages/gym/envs/registration.py:216: UserWarning: WARN: Overriding environment ZaxxonNoFrameskip-v0
#   logger.warn("Overriding environment {}".format(id))
# /home/phu/Dropbox/general_backup/anaconda3/envs/gen_env/lib/python3.10/site-packages/gym/envs/registration.py:216: UserWarning: WARN: Overriding environment Zaxxon-v4
#   logger.warn("Overriding environment {}".format(id))
# /home/phu/Dropbox/general_backup/anaconda3/envs/gen_env/lib/python3.10/site-packages/gym/envs/registration.py:216: UserWarning: WARN: Overriding environment ZaxxonDeterministic-v4
#   logger.warn("Overriding environment {}".format(id))
# /home/phu/Dropbox/general_backup/anaconda3/envs/gen_env/lib/python3.10/site-packages/gym/envs/registration.py:216: UserWarning: WARN: Overriding environment ZaxxonNoFrameskip-v4
#   logger.warn("Overriding environment {}".format(id))
# /home/phu/Dropbox/general_backup/anaconda3/envs/gen_env/lib/python3.10/site-packages/gym/envs/registration.py:216: UserWarning: WARN: Overriding environment Zaxxon-ram-v0
#   logger.warn("Overriding environment {}".format(id))
# /home/phu/Dropbox/general_backup/anaconda3/envs/gen_env/lib/python3.10/site-packages/gym/envs/registration.py:216: UserWarning: WARN: Overriding environment Zaxxon-ramDeterministic-v0
#   logger.warn("Overriding environment {}".format(id))
# /home/phu/Dropbox/general_backup/anaconda3/envs/gen_env/lib/python3.10/site-packages/gym/envs/registration.py:216: UserWarning: WARN: Overriding environment Zaxxon-ramNoFrameskip-v0
#   logger.warn("Overriding environment {}".format(id))
# /home/phu/Dropbox/general_backup/anaconda3/envs/gen_env/lib/python3.10/site-packages/gym/envs/registration.py:216: UserWarning: WARN: Overriding environment Zaxxon-ram-v4
#   logger.warn("Overriding environment {}".format(id))
# /home/phu/Dropbox/general_backup/anaconda3/envs/gen_env/lib/python3.10/site-packages/gym/envs/registration.py:216: UserWarning: WARN: Overriding environment Zaxxon-ramDeterministic-v4
#   logger.warn("Overriding environment {}".format(id))
# /home/phu/Dropbox/general_backup/anaconda3/envs/gen_env/lib/python3.10/site-packages/gym/envs/registration.py:216: UserWarning: WARN: Overriding environment Zaxxon-ramNoFrameskip-v4
#   logger.warn("Overriding environment {}".format(id))

# %% [markdown]
# ## Feed-Forward Network

# %%
class PolicyNetwork(Module):
    def __init__(self, input_dim, output_dim):
        super().__init__()
        self.model = Sequential(
            Linear(input_dim, 64),
            ReLU(),
            Linear(64, 64),
            ReLU(),
            Linear(64, output_dim)
        )
    
    def forward(self, observation):
        if isinstance(observation, np.ndarray):
            observation = torch.tensor(observation, dtype=torch.float)
        return self.model(observation)

# %% [markdown]
# ## Reward Functions

# %%
class RewardStrategy:
    def __init__(self, gamma, gae_lambda):
        self.gamma = gamma
        self.gae_lambda = gae_lambda

class RewardsToGo(RewardStrategy):
    def __init__(self, gamma, gae_lambda):
        super().__init__(gamma, gae_lambda)

    def compute_advantages(self, rewards, values, masks):
        batch_rtgs = []
        for episode_rewards in reversed(rewards):
            discounted_reward = 0
            for reward in reversed(episode_rewards):
                discounted_reward = reward + discounted_reward * self.gamma
                batch_rtgs.insert(0, discounted_reward)
        
        batch_rtgs = torch.tensor(batch_rtgs, dtype=torch.float)
        adv = batch_rtgs - values
        return batch_rtgs, adv

class GeneralizedAdvantage(RewardStrategy):
    def __init__(self, gamma, gae_lambda):
        super().__init__(gamma, gae_lambda)
        self.coeff = gamma * gae_lambda

    def compute_advantages(self, rewards, values, masks):
        flat_rewards = torch.flatten(rewards)
        batch_size = len(flat_rewards)
        advantage = np.zeros(batch_size + 1)
        advantage[batch_size - 1] = flat_rewards[batch_size - 1] - values[batch_size - 1]

        for i in reversed(range(batch_size - 1)):
            delta = flat_rewards[i] + (masks[i] * self.gamma * values[i + 1]) - values[i]
            advantage[i] = delta + (masks[i] * self.coeff * advantage[i + 1])
        
        advantage = torch.tensor(advantage[:batch_size])
        batch_returns = advantage + np.squeeze(values)
        batch_returns = torch.tensor(batch_returns, dtype=torch.float)
        return batch_returns, advantage

# %%
kjdiuhjkasdefkjkjslkj

# %% [markdown]
# ## Objective Functions

# %%
class Objective:
    def __init__(self, epsilon):
        self.epsilon = epsilon

class SurrogateObjectiveClip(Objective):
    def __init__(self, epsilon):
        super().__init__(epsilon)

    def get_loss(self, ratios, advantage):
        surrogate_loss = ratios * advantage
        clipped_surrogate_loss = torch.clamp(ratios, 1 - self.epsilon, 1 + self.epsilon) * advantage

        return (-torch.min(surrogate_loss, clipped_surrogate_loss)).mean()

class SurrogateObjectiveNoClip(Objective):
    def __init__(self, epsilon):
        super().__init__(epsilon)

    def get_loss(self, ratios, advantage):
        surrogate_loss = ratios * advantage

        return (-torch.min(surrogate_loss)).mean()

# %% [markdown]
# ## PPO

# %%
class PPO:
    def __init__(self, env, policy_class, reward_class, objective_class, seed: int = 260):
        # Initialize hyperparameters
        self.timesteps_per_batch = 100000
        self.max_timesteps_per_episode = 300
        self.updates_per_iteration = 5
        self.lr = 3e-4
        self.gamma = 0.99
        self.gae_lambda = 0.95
        self.epsilon = 0.2
        self.critic_discount = 0.5
        self.alpha = 0.001
        self.seed = seed
        torch.manual_seed(self.seed)

        # Initialize other parameters
        self.render = False
        self.render_interval = 10

        # Set environment params
        self.env = env
        self.env1 = copy.deepcopy(env)
        self.observation_dim = env.observation_space.shape[0]
        self.action_dim = env.action_space.shape[0]

        # Initialize networks
        self.actor = policy_class(self.observation_dim, self.action_dim)
        self.critic = policy_class(self.observation_dim, 1)
        self.critic1 = policy_class(self.observation_dim, 1)

        # Initialize advantage and objective functions
        self.reward_strategy = reward_class(self.gamma, self.gae_lambda)
        self.objective = objective_class(self.epsilon)

        # Initialize optimizers
        self.actor_optimizer = Adam(self.actor.parameters(), lr=self.lr)
        self.critic_optimizer = Adam(self.critic.parameters(), lr=self.lr)
        self.critic_optimizer1 = Adam(self.critic1.parameters(), lr=self.lr)

        # Initialize covariance matrix
        self.cov_matrix = torch.diag(torch.full(size=(self.action_dim,), fill_value=0.5))

        # Initialize logger
        self.logger = {
            "delta_time": time.time_ns(),
            "current_timesteps": 0,
            "current_iterations": 0,
            "batch_lens": [],
            "batch_rewards": [],
            "actor_losses": [],
            "total_losses": [],
            "theta": [],
            "theta_dot": [],
            "reward": []
        }

        # Initialize results
        self.results = {
            "iteration_count": [],
            "accumulated_rewards": [],
            "total_losses": [],
            "theta": [],
            "theta_dot": [],
            "reward": []
        }
    
    def train(self, max_timesteps):
        current_timesteps, current_iterations = 0, 0
        while current_timesteps < max_timesteps:
            # Run batch simulations (set of trajectories from running policy in the environment)
            batch, batch1 = self.batch_simulation()
            batch_obs, batch_acts, batch_log_probs, batch_rewards, batch_lens, batch_masks = batch
            batch_obs1, batch_acts1, batch_log_probs1, batch_rewards1, batch_lens1, batch_masks1 = batch1
            
#             batch_rewards = batch_rewards + batch_rewards1
#             print (batch_rewards)
#             input()
            # Increment timesteps and iterations
            current_timesteps += np.sum(batch_lens)
            current_iterations += 1
            self.logger["current_timesteps"] = current_timesteps
            self.logger["current_iterations"] = current_iterations

            # Calculate returns and advantages
            values, _ = self.evaluate(batch_obs, batch_acts)
            values1, _ = self.evaluate(batch_obs1, batch_acts1)
#             print ('batch_rewards:', batch_rewards)
#             print ('values.detach():', values.detach())
#             print ('batch_masks:', batch_rewards)
            batch_returns, adv = self.reward_strategy.compute_advantages(batch_rewards, values.detach(), batch_masks)
            batch_returns1, adv1 = self.reward_strategy.compute_advantages(batch_rewards1, values1.detach(), batch_masks1)
            # Normalize advantages
            adv = (adv - adv.mean()) / (adv.std() + 1e-10)
            adv1 = (adv1 - adv1.mean()) / (adv1.std() + 1e-10)
            # Update the networks
            for _ in range(self.updates_per_iteration):
                V_phi, log_probs = self.evaluate(batch_obs, batch_acts)
                policy_ratios = torch.exp(log_probs - batch_log_probs)
                
                V_phi1, log_probs1 = self.evaluate(batch_obs1, batch_acts1)
                policy_ratios1 = torch.exp(log_probs1 - batch_log_probs1)
                
                # Calculate actor and critic losses
#                 print ('loss:',self.objective.get_loss(policy_ratios, adv))
#                 input()
                # torch.cat((losses_q.reshape(1), this_loss_q), dim=0)
#                 actor_loss  = torch.mean(torch.cat((self.objective.get_loss(policy_ratios, adv).reshape(1), self.objective.get_loss(policy_ratios1, adv1).reshape(1)),0))
                actor_loss  = self.objective.get_loss(policy_ratios, adv)
                critic_loss = MSELoss()(V_phi, batch_returns)
#                 critic_loss1 = MSELoss()(V_phi1, batch_returns1)
                
                # Calculate gradients and perform backward propagation for actor/critic networks
                self.actor_optimizer.zero_grad()
                actor_loss.backward(retain_graph=True)
                self.actor_optimizer.step()
                
                self.critic_optimizer.zero_grad()
                critic_loss.backward()
                self.critic_optimizer.step()
                
#                 self.critic_optimizer1.zero_grad()
#                 critic_loss1.backward()
#                 self.critic_optimizer1.step()
                
                self.logger["actor_losses"].append(actor_loss.detach())
                self.logger["total_losses"].append(actor_loss.detach() + self.critic_discount * critic_loss.detach())

            self._log_summary()

    def batch_simulation(self):
        batch_obs = []
        batch_acts = []
        batch_log_probs = []
        batch_rewards = []
        batch_lens = []
        batch_masks = []
        theta = []
        theta_dot = []
        
        
        batch_obs1 = []
        batch_acts1 = []
        batch_log_probs1 = []
        batch_rewards1 = []
        batch_masks1 = []
        

        current_iteration = self.logger["current_iterations"]
        t = 0
        while t < self.timesteps_per_batch:
            episode_rewards = []
            episode_rewards1 = []
            
            observation = self.env.reset()
            observation1 = self.env1.reset()
            observation1 = observation
            
            is_done = False
            is_done1 = False
            
            episode_t = 0
            temp_obs = self.convert_to_rad(observation)
            theta.append(temp_obs[0])
            theta_dot.append(temp_obs[1])
            
            # Run an episode
            for episode_t in range(self.max_timesteps_per_episode):
                if self.render and len(batch_lens) == 0 and (current_iteration % self.render_interval == 0):
                    self.env.render()
                
                # Calculate an action and make that action in the environment
                s1 = observation
                batch_obs.append(observation)
                action, log_prob = self.get_action(observation)
                observation, reward, is_done, _ = self.env.step(action)
                s11 = observation
                
                # Track rewards, actions, and log probs
                batch_acts.append(action)
                batch_log_probs.append(log_prob)
                batch_masks.append(0 if is_done else 1)
                
                # Calculate an action and make that action in the environment
                s2 = observation1
                batch_obs1.append(observation1)
                action1, log_prob1 = self.get_action(observation1)
                observation1, reward1, is_done1, _ = self.env1.step(action1)
                s21 = observation1
                
                # Track rewards, actions, and log probs
                reward, reward1 = self.le_reward(s1, s11, s2, s21)
                episode_rewards.append(reward)
                episode_rewards1.append(reward1)
                batch_acts1.append(action1)
                batch_log_probs1.append(log_prob1)
                batch_masks1.append(0 if is_done1 else 1)
                
                
 
                t += 1
                if is_done or is_done1:
                    break
#             print (episode_t)
#             print (is_done,is_done1)
#             input()
            batch_lens.append(episode_t + 1)
            batch_rewards.append(episode_rewards)
            batch_rewards1.append(episode_rewards1)

        
        # Cast everything we need to a tensor
        batch_obs = torch.tensor(batch_obs, dtype=torch.float)
        batch_acts = torch.tensor(batch_acts, dtype=torch.float)
        batch_log_probs = torch.tensor(batch_log_probs, dtype=torch.float)
        batch_rewards = torch.tensor(batch_rewards, dtype=torch.float)
        batch_masks = torch.tensor(batch_masks, dtype=torch.float)
        
        batch_obs1 = torch.tensor(batch_obs1, dtype=torch.float)
        batch_acts1 = torch.tensor(batch_acts1, dtype=torch.float)
        batch_log_probs1 = torch.tensor(batch_log_probs1, dtype=torch.float)
        batch_rewards1 = torch.tensor(batch_rewards1, dtype=torch.float)
        batch_masks1 = torch.tensor(batch_masks1, dtype=torch.float)

        self.logger["batch_rewards"] = batch_rewards
        self.logger["batch_lens"] = batch_lens
        self.logger["theta"] = theta
        self.logger["theta_dot"] = theta_dot

        return [batch_obs, batch_acts, batch_log_probs, batch_rewards, batch_lens, batch_masks], [batch_obs1, batch_acts1, batch_log_probs1, batch_rewards1, batch_lens, batch_masks1]
    
    def le_reward (self, s1, s11, s2, s21):
#         print ('before')
#         print ("s1:", s1)
#         print ("s2:", s2)
#         print ("s11:", s11)
#         print ("s21:", s21)
        if np.array_equal(s1, s2):
            s2 = s2+1e-4
        temp = [s1, s11, s2, s21]
        s1 = self.convert_to_rad(s1)
        s11 = self.convert_to_rad(s11)
        s2 = self.convert_to_rad(s2)
        s21 = self.convert_to_rad(s21)
        temp2 = [s1, s11, s2, s21]
#         if np.any(np.isnan(s1)) or np.any(np.isnan(s11)) or np.any(np.isnan(s2)) or np.any(np.isnan(s21)):
#             print ("s1:", s1)
#             print ("s2:", s2)
#             print ("s11:", s11)
#             print ("s21:", s21)
#         if np.any(np.isnan(s1)):
#             print ('after')
#             print ("s1:", s1)
#             print ("s2:", s2)
#             print ("s11:", s11)
#             print ("s21:", s21)
        #GS for s
        norm1 = np.linalg.norm(s1)
        s1 = s1/norm1
        
        GSC1 = np.dot(s2, s1)
        s2 = s2 - GSC1*s1
        
        norm2 = np.linalg.norm(s2)
#         s2 = s2/norm2
        
        #GS for s1
        norm11 = np.linalg.norm(s11)
        s11 = s11/norm11
        
        GSC1 = np.dot(s21, s11)
        s21 = s21 - GSC1*s11
        
        norm21 = np.linalg.norm(s21)
#         s21 = s21/norm21
        if np.log(norm11/norm1) ==np.inf or np.log(norm21/norm2) == np.inf:
            print ('temp:', temp)
            print ('temp2:', temp2)
            print ("s1:", s1)
            print ("s2:", s2)
            print ("s11:", s11)
            print ("s21:", s21)
            print ("lamda1:", np.log(norm11/norm1))
            print ("lamda2:", np.log(norm21/norm2))
#         print ("norm11:", norm11)
#         print ("norm21:", norm21)
#         return 2*np.log(norm11/norm1) - self.alpha*action**2, np.log(norm21/norm2)
        return np.log(norm11/norm1), np.log(norm21/norm2)
    
    def convert_to_rad(self,s):
        return np.array([np.arctan2(s[0],s[1]),s[2]])
    
    def evaluate(self, observations, actions):
        # Calculate the values of each observation
        values = self.critic(observations).squeeze()

        # Calculate the log probabilities of each action
        mean = self.actor(observations)
#         print (values,observations)
#         input()
        distribution = MultivariateNormal(mean, self.cov_matrix)
        log_probs = distribution.log_prob(actions)

        return values, log_probs
    
    def get_action(self, observation):
        # Sample the distribution for an action
        mean = self.actor(observation)
        distribution = MultivariateNormal(mean, self.cov_matrix)
        action = distribution.sample()

        # Calculate the log probability for the sampled action
        log_prob = distribution.log_prob(action)

        return action.detach().numpy(), log_prob.detach()

    def get_results(self):
        return self.results

    def _log_summary(self):
        delta_t = self.logger["delta_time"]
        self.logger["delta_time"] = time.time_ns()
        delta_t = str(round((self.logger["delta_time"] - delta_t) / 1e9, 2))

        # Calculate everything we want to log
        current_timestep = self.logger["current_timesteps"]
        current_iteration = self.logger["current_iterations"]
#         print (self.logger["batch_lens"])
#         input()
        avg_ep_lens = np.mean(self.logger["batch_lens"])
        avg_ep_rewards = np.mean([np.sum(np.array(ep_rewards)) for ep_rewards in self.logger["batch_rewards"]])
        avg_actor_loss = np.mean([losses.float().mean() for losses in self.logger["actor_losses"]])
        avg_total_loss = np.mean([losses.float().mean() for losses in self.logger["total_losses"]])
        print(self.logger["batch_rewards"])
        mean_each_traj = np.mean(np.array(self.logger["batch_rewards"]), axis=1)
        # Print logging statements
        display.clear_output()
        print()
        print(f"-------------------- Iteration #{current_iteration} --------------------")
        print(f"Average Episodic Length: {avg_ep_lens:.2f}")
        print(f"Average Episodic Return: {avg_ep_rewards:.2f}")
        print(f"Average Actor Loss: {avg_actor_loss:.5f}")
        print(f"Average Total Loss: {avg_total_loss:.5f}")
        print(f"Current Timestep: {current_timestep}")
        print(f"Iteration took: {delta_t} secs")
        print(f"------------------------------------------------------")
        print()

        # Save data for displaying graphs
        self.results["iteration_count"].append(current_iteration)
        self.results["accumulated_rewards"].append(avg_ep_rewards)
        self.results["total_losses"].append(avg_total_loss)
        self.results["theta"] = self.logger["theta"]
        self.results["theta_dot"] = self.logger["theta_dot"]
        self.results["reward"] = list(mean_each_traj)
        
        display_results2(self.results, " ")
        input()
        # Reset batch-specific logging data
        self.logger["batch_lens"] = []
        self.logger["batch_rewards"] = []
        self.logger["actor_losses"] = []
        self.logger["total_losses"] = []
        self.results["theta"] = []
        self.results["theta_dot"] = []
        self.results["reward"] = []

# %% [markdown]
# ## Display Function

# %%
def display_results(model_results, settings_str):
    fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(25, 10))
    fig.suptitle(settings_str)

    # Display rewards graph
    ax1.plot(model_results["iteration_count"], model_results["accumulated_rewards"])
    ax1.set_title("Rewards")
    ax1.set_xlabel("Iteration Count")
    ax1.set_ylabel("Average Episodic Reward")

    # Display total losses graph
    ax2.plot(model_results["iteration_count"], model_results["total_losses"])
    ax2.set_title("Losses")
    ax2.set_xlabel("Iteration Count")
    ax2.set_ylabel("Average Total Loss")

    plt.show()
    
def display_results2(model_results, settings_str):
    fig = plt.figure(figsize=(6,5))
    ax = fig.add_subplot(111)

#     plot1 = ax.imshow(np.flip(zs[:,0].reshape(21,21),1).T, extent=[0,2*np.pi , -8,8],aspect='auto',cmap='plasma',interpolation="bilinear")
    plot1 = ax.scatter(model_results['theta'], model_results['theta_dot'], c=model_results['reward'], cmap='plasma')
    # ax.plot(tjt_fixed,tjt[1],linewidth=3, c='white')
    cbar1 = fig.colorbar(plot1, shrink=0.6, aspect=5)
    font = {'size': 20}
    ax.tick_params('x', labelsize=font['size'])
    ax.tick_params('y', labelsize=font['size'])
    ax.set_ylabel(r"$\mathbf{\dot{\Theta}}$", fontsize = 20)
    ax.set_xlabel(r"$\mathbf{\Theta},rad$", fontsize = 20)
    # plt.title ('Simple Pendulum T=5s', fontsize = 20)


    plt.tight_layout()
    plt.show()

# %% [markdown]
# ## Training

# %%
MAX_TIMESTEPS = 1000000

class TrainingResult:
    def __init__(self, label, reward_class, objective_class):
        self.label = label
        self.reward_class = reward_class
        self.objective_class = objective_class
        self.results = {}
    
    def set_results(self, results):
        self.results = results
        input()

training_results = [
    TrainingResult("RewardsToGo-NoClip", RewardsToGo, SurrogateObjectiveNoClip),
    TrainingResult("RewardsToGo-Clip", RewardsToGo, SurrogateObjectiveNoClip),
    TrainingResult("GeneralizedAdvantage-NoClip", GeneralizedAdvantage, SurrogateObjectiveNoClip),
    TrainingResult("GeneralizedAdvantage-Clip", GeneralizedAdvantage, SurrogateObjectiveClip),
]

def train_model(training_result, max_timesteps=MAX_TIMESTEPS):
    with gym.make("Pendulum-v1") as pendulum_env:
        ppo_model = PPO(pendulum_env, PolicyNetwork, training_result.reward_class, training_result.objective_class)
        ppo_model.train(max_timesteps=max_timesteps)
        training_result.set_results(ppo_model.get_results())
        
        display_results(training_result.results, training_result.label)

# %%
np.arctan2(0.64433783,-0.764741)
# Out:
# 2.4414355767004925

# %%
train_model(training_results[1])
# Out:
# -------------------- Iteration #2 --------------------
# Average Episodic Length: 300.00
# Average Episodic Return: -0.19
# Average Actor Loss: 5.61245
# Average Total Loss: 5.78604
# Current Timestep: 200400
# Iteration took: 1094.31 secs
# ------------------------------------------------------
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[14], line 1
# ----> 1 train_model(training_results[1])
#
# Cell In[12], line 24, in train_model(training_result, max_timesteps)
#      22 with gym.make("Pendulum-v1") as pendulum_env:
#      23     ppo_model = PPO(pendulum_env, PolicyNetwork, training_result.reward_class, training_result.objective_class)
# ---> 24     ppo_model.train(max_timesteps=max_timesteps)
#      25     training_result.set_results(ppo_model.get_results())
#      27     display_results(training_result.results, training_result.label)
#
# Cell In[10], line 128, in PPO.train(self, max_timesteps)
#     125     self.logger["actor_losses"].append(actor_loss.detach())
#     126     self.logger["total_losses"].append(actor_loss.detach() + self.critic_discount * critic_loss.detach())
# --> 128 self._log_summary()
#
# Cell In[10], line 357, in PPO._log_summary(self)
#     354 self.results["reward"] = list(mean_each_traj)
#     356 display_results2(self.results, " ")
# --> 357 input()
#     358 # Reset batch-specific logging data
#     359 self.logger["batch_lens"] = []
#
# File ~/Dropbox/general_backup/anaconda3/envs/gen_env/lib/python3.10/site-packages/ipykernel/kernelbase.py:1175, in Kernel.raw_input(self, prompt)
#    1171 if not self._allow_stdin:
#    1172     raise StdinNotImplementedError(
#    1173         "raw_input was called, but this frontend does not support input requests."
#    1174     )
# -> 1175 return self._input_request(
#    1176     str(prompt),
#    1177     self._parent_ident["shell"],
#    1178     self.get_parent("shell"),
#    1179     password=False,
#    1180 )
#
# File ~/Dropbox/general_backup/anaconda3/envs/gen_env/lib/python3.10/site-packages/ipykernel/kernelbase.py:1217, in Kernel._input_request(self, prompt, ident, parent, password)
#    1214             break
#    1215 except KeyboardInterrupt:
#    1216     # re-raise KeyboardInterrupt, to truncate traceback
# -> 1217     raise KeyboardInterrupt("Interrupted by user") from None
#    1218 except Exception:
#    1219     self.log.warning("Invalid Message:", exc_info=True)
#
# KeyboardInterrupt: Interrupted by user

# %%
train_model(training_results[1])

# %%
train_model(training_results[2])

# %%
train_model(training_results[3])
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipykernel_327733/4221363707.py in <module>
# ----> 1 train_model(training_results[3])
#
# /tmp/ipykernel_327733/2440158718.py in train_model(training_result, max_timesteps)
#      21     with gym.make("lorenz_u_v0") as pendulum_env:
#      22         ppo_model = PPO(pendulum_env, PolicyNetwork, training_result.reward_class, training_result.objective_class)
# ---> 23         ppo_model.train(max_timesteps=max_timesteps)
#      24         training_result.set_results(ppo_model.get_results())
#      25         display_results(training_result.results, training_result.label)
#
# /tmp/ipykernel_327733/1487357381.py in train(self, max_timesteps)
#      59         while current_timesteps < max_timesteps:
#      60             # Run batch simulations (set of trajectories from running policy in the environment)
# ---> 61             batch_obs, batch_acts, batch_log_probs, batch_rewards, batch_lens, batch_masks = self.batch_simulation()
#      62
#      63             # Increment timesteps and iterations
#
# /tmp/ipykernel_327733/1487357381.py in batch_simulation(self)
#     115             for episode_t in range(self.max_timesteps_per_episode):
#     116                 if self.render and len(batch_lens) == 0 and (current_iteration % self.render_interval == 0):
# --> 117                     self.env.render()
#     118
#     119                 # Calculate an action and make that action in the environment
#
# ~/anaconda3/envs/cmpe258/lib/python3.9/site-packages/gym/wrappers/order_enforcing.py in render(self, **kwargs)
#      49                 "set `disable_render_order_enforcing=True` on the OrderEnforcer wrapper."
#      50             )
# ---> 51         return self.env.render(**kwargs)
#
# ~/anaconda3/envs/cmpe258/lib/python3.9/site-packages/gym/wrappers/env_checker.py in render(self, **kwargs)
#      55             return passive_env_render_check(self.env, **kwargs)
#      56         else:
# ---> 57             return self.env.render(**kwargs)
#
# ~/Dropbox/general_backup/mastering_chaos/Lorenz_envs/Lorenz_envs/envs/lorenz_u_v0.py in render(self, mode)
#     130             return self._renderer()
#     131         else:
# --> 132             return self._render(mode)
#     133
#     134     def _render(self, mode="human"):
#
# ~/Dropbox/general_backup/mastering_chaos/Lorenz_envs/Lorenz_envs/envs/lorenz_u_v0.py in _render(self, mode)
#     139         plt.title('Lorenz attractor')
#     140         plt.draw()
# --> 141         plt.savefig('Lorenz_ppo.png')
#     142     # def _render(self, mode="human"):
#     143         # assert mode in self.metadata["render_modes"]
#
# ~/anaconda3/envs/cmpe258/lib/python3.9/site-packages/matplotlib/pyplot.py in savefig(*args, **kwargs)
#     957     fig = gcf()
#     958     res = fig.savefig(*args, **kwargs)
# --> 959     fig.canvas.draw_idle()   # need this if 'transparent=True' to reset colors
#     960     return res
#     961
#
# ~/anaconda3/envs/cmpe258/lib/python3.9/site-packages/matplotlib/backend_bases.py in draw_idle(self, *args, **kwargs)
#    2058         if not self._is_idle_drawing:
#    2059             with self._idle_draw_cntx():
# -> 2060                 self.draw(*args, **kwargs)
#    2061
#    2062     @property
#
# ~/anaconda3/envs/cmpe258/lib/python3.9/site-packages/matplotlib/backends/backend_agg.py in draw(self)
#     434              (self.toolbar._wait_cursor_for_draw_cm() if self.toolbar
#     435               else nullcontext()):
# --> 436             self.figure.draw(self.renderer)
#     437             # A GUI class may be need to update a window using this draw, so
#     438             # don't forget to call the superclass.
#
# ~/anaconda3/envs/cmpe258/lib/python3.9/site-packages/matplotlib/artist.py in draw_wrapper(artist, renderer, *args, **kwargs)
#      71     @wraps(draw)
#      72     def draw_wrapper(artist, renderer, *args, **kwargs):
# ---> 73         result = draw(artist, renderer, *args, **kwargs)
#      74         if renderer._rasterizing:
#      75             renderer.stop_rasterizing()
#
# ~/anaconda3/envs/cmpe258/lib/python3.9/site-packages/matplotlib/artist.py in draw_wrapper(artist, renderer)
#      48                 renderer.start_filter()
#      49
# ---> 50             return draw(artist, renderer)
#      51         finally:
#      52             if artist.get_agg_filter() is not None:
#
# ~/anaconda3/envs/cmpe258/lib/python3.9/site-packages/matplotlib/figure.py in draw(self, renderer)
#    2808
#    2809             self.patch.draw(renderer)
# -> 2810             mimage._draw_list_compositing_images(
#    2811                 renderer, self, artists, self.suppressComposite)
#    2812
#
# ~/anaconda3/envs/cmpe258/lib/python3.9/site-packages/matplotlib/image.py in _draw_list_compositing_images(renderer, parent, artists, suppress_composite)
#     130     if not_composite or not has_images:
#     131         for a in artists:
# --> 132             a.draw(renderer)
#     133     else:
#     134         # Composite any adjacent images together
#
# ~/anaconda3/envs/cmpe258/lib/python3.9/site-packages/matplotlib/artist.py in draw_wrapper(artist, renderer)
#      48                 renderer.start_filter()
#      49
# ---> 50             return draw(artist, renderer)
#      51         finally:
#      52             if artist.get_agg_filter() is not None:
#
# ~/anaconda3/envs/cmpe258/lib/python3.9/site-packages/mpl_toolkits/mplot3d/axes3d.py in draw(self, renderer)
#     471
#     472             # Then rest
# --> 473             super().draw(renderer)
#     474
#     475     def get_axis_position(self):
#
# ~/anaconda3/envs/cmpe258/lib/python3.9/site-packages/matplotlib/artist.py in draw_wrapper(artist, renderer)
#      48                 renderer.start_filter()
#      49
# ---> 50             return draw(artist, renderer)
#      51         finally:
#      52             if artist.get_agg_filter() is not None:
#
# ~/anaconda3/envs/cmpe258/lib/python3.9/site-packages/matplotlib/axes/_base.py in draw(self, renderer)
#    3080             renderer.stop_rasterizing()
#    3081
# -> 3082         mimage._draw_list_compositing_images(
#    3083             renderer, self, artists, self.figure.suppressComposite)
#    3084
#
# ~/anaconda3/envs/cmpe258/lib/python3.9/site-packages/matplotlib/image.py in _draw_list_compositing_images(renderer, parent, artists, suppress_composite)
#     130     if not_composite or not has_images:
#     131         for a in artists:
# --> 132             a.draw(renderer)
#     133     else:
#     134         # Composite any adjacent images together
#
# ~/anaconda3/envs/cmpe258/lib/python3.9/site-packages/mpl_toolkits/mplot3d/art3d.py in draw(self, renderer)
#     530     def draw(self, renderer):
#     531         with cbook._setattr_cm(self, _in_draw=True):
# --> 532             super().draw(renderer)
#     533
#     534     def set_sort_zpos(self, val):
#
# ~/anaconda3/envs/cmpe258/lib/python3.9/site-packages/matplotlib/artist.py in draw_wrapper(artist, renderer)
#      48                 renderer.start_filter()
#      49
# ---> 50             return draw(artist, renderer)
#      51         finally:
#      52             if artist.get_agg_filter() is not None:
#
# ~/anaconda3/envs/cmpe258/lib/python3.9/site-packages/matplotlib/collections.py in draw(self, renderer)
#     989     def draw(self, renderer):
#     990         self.set_sizes(self._sizes, self.figure.dpi)
# --> 991         super().draw(renderer)
#     992
#     993
#
# ~/anaconda3/envs/cmpe258/lib/python3.9/site-packages/matplotlib/artist.py in draw_wrapper(artist, renderer)
#      48                 renderer.start_filter()
#      49
# ---> 50             return draw(artist, renderer)
#      51         finally:
#      52             if artist.get_agg_filter() is not None:
#
# ~/anaconda3/envs/cmpe258/lib/python3.9/site-packages/matplotlib/collections.py in draw(self, renderer)
#     403             else:
#     404                 combined_transform = transform
# --> 405             extents = paths[0].get_extents(combined_transform)
#     406             if (extents.width < self.figure.bbox.width
#     407                     and extents.height < self.figure.bbox.height):
#
# ~/anaconda3/envs/cmpe258/lib/python3.9/site-packages/matplotlib/path.py in get_extents(self, transform, **kwargs)
#     626             for curve, code in self.iter_bezier(**kwargs):
#     627                 # places where the derivative is zero can be extrema
# --> 628                 _, dzeros = curve.axis_aligned_extrema()
#     629                 # as can the ends of the curve
#     630                 xys.append(curve([0, *dzeros, 1]))
#
# ~/anaconda3/envs/cmpe258/lib/python3.9/site-packages/matplotlib/bezier.py in axis_aligned_extrema(self)
#     298         roots = []
#     299         for i, pi in enumerate(dCj.T):
# --> 300             r = np.roots(pi[::-1])
#     301             roots.append(r)
#     302             dims.append(np.full_like(r, i))
#
# ~/anaconda3/envs/cmpe258/lib/python3.9/site-packages/numpy/core/overrides.py in roots(*args, **kwargs)
#
# ~/anaconda3/envs/cmpe258/lib/python3.9/site-packages/numpy/lib/polynomial.py in roots(p)
#     252         A = diag(NX.ones((N-2,), p.dtype), -1)
#     253         A[0,:] = -p[1:] / p[0]
# --> 254         roots = eigvals(A)
#     255     else:
#     256         roots = NX.array([])
#
# ~/anaconda3/envs/cmpe258/lib/python3.9/site-packages/numpy/core/overrides.py in eigvals(*args, **kwargs)
#
# ~/anaconda3/envs/cmpe258/lib/python3.9/site-packages/numpy/linalg/linalg.py in eigvals(a)
#    1048     _assert_stacked_2d(a)
#    1049     _assert_stacked_square(a)
# -> 1050     _assert_finite(a)
#    1051     t, result_t = _commonType(a)
#    1052
#
# ~/anaconda3/envs/cmpe258/lib/python3.9/site-packages/numpy/linalg/linalg.py in _assert_finite(*arrays)
#     205 def _assert_finite(*arrays):
#     206     for a in arrays:
# --> 207         if not isfinite(a).all():
#     208             raise LinAlgError("Array must not contain infs or NaNs")
#     209
#
# ~/anaconda3/envs/cmpe258/lib/python3.9/site-packages/numpy/core/_methods.py in _all(a, axis, dtype, out, keepdims, where)
#      61     # Parsing keyword arguments is currently fairly slow, so avoid it for now
#      62     if where is True:
# ---> 63         return umr_all(a, axis, dtype, out, keepdims)
#      64     return umr_all(a, axis, dtype, out, keepdims, where=where)
#      65
#
# KeyboardInterrupt:

# %%
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(25, 10))

fig.suptitle("All Settings")
x = training_results[0].results["iteration_count"]

ax1.set_title("Rewards")
ax1.set_xlabel("Iteration Count")
ax1.set_ylabel("Average Episodic Reward")

ax2.set_title("Losses")
ax2.set_xlabel("Iteration Count")
ax2.set_ylabel("Average Total Loss")

for training_result in training_results:
    ax1.plot(x, training_result.results["accumulated_rewards"], label=training_result.label)
    ax2.plot(x, training_result.results["total_losses"], label=training_result.label)

ax1.legend()
ax2.legend()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[155], line 4
#       1 fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(25, 10))
#       3 fig.suptitle("All Settings")
# ----> 4 x = training_results[0].results["iteration_count"]
#       6 ax1.set_title("Rewards")
#       7 ax1.set_xlabel("Iteration Count")
#
# KeyError: 'iteration_count'
