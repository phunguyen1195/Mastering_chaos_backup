# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from scipy.interpolate import make_interp_spline

# %%
x=np.load("/home/phu/Downloads/pendulum_points_01_500_pi.npy")
zs = np.load("/home/phu/Downloads/pendulum_sample_01_500_pi.npy")
# tjt=np.load("pendulum_trajectory.npy")

T = 500
fig = plt.figure(figsize=(5,5))
ax = fig.add_subplot(111)

plot1 = ax.imshow(zs.reshape(63,200).T, extent=[ 0,2*np.pi,-10 ,10 ],aspect='auto',cmap='plasma',interpolation="bilinear")
# ax.plot(tjt[1][1::],tjt[0][1::],linewidth=3, c='white')
# cbar1 = fig.colorbar(plot1, shrink=0.6, aspect=5)
font = {'size': 20}
ax.tick_params('x', labelsize=font['size'])
ax.tick_params('y', labelsize=font['size'])
ax.set_xlabel('Angle', fontsize = 20)
ax.set_ylabel('Angular Velocity', fontsize = 20)
# plt.title ('Simple Pendulum trajectory stablization', fontsize = 15)
fig.tight_layout()
fig.savefig('pendulum-trajectory.png', transparent=True)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[6], line 9
#       6 fig = plt.figure(figsize=(5,5))
#       7 ax = fig.add_subplot(111)
# ----> 9 plot1 = ax.imshow(zs.reshape(63,200).T, extent=[ 0,2*np.pi,-10 ,10 ],aspect='auto',cmap='plasma',interpolation="bilinear")
#      10 # ax.plot(tjt[1][1::],tjt[0][1::],linewidth=3, c='white')
#      11 # cbar1 = fig.colorbar(plot1, shrink=0.6, aspect=5)
#      12 font = {'size': 20}
#
# ValueError: cannot reshape array of size 3200 into shape (63,200)

# %%
fig = plt.figure(figsize=(15,15))
ax = fig.add_subplot(111)

plot1 = ax.scatter(x.T[0], x.T[1], 
                   c=zs, cmap=plt.cm.plasma,vmin=zs.min(), vmax=zs.max(), s=500, marker="s")
cbar1 = fig.colorbar(plot1, shrink=0.6, aspect=5)
ax.set_xlabel('angle from the lowest point')
ax.set_ylabel('angular velocity')
plt.title ('le of simple pendulum, at T={}, +- [0,2pi] angle from the lowest point and +- 8 angular velocity'.format(T))
# Out:
# Text(0.5, 1.0, 'le of simple pendulum, at T=500, +- [0,2pi] angle from the lowest point and +- 8 angular velocity')

# %%
x
# Out:
# array([[  0. , -10. ],
#        [  0. ,  -9.9],
#        [  0. ,  -9.8],
#        ...,
#        [  6.2,   9.7],
#        [  6.2,   9.8],
#        [  6.2,   9.9]])

# %%
zs
# Out:
# array([-0.49041352, -0.48512547, -0.47670195, ..., -0.49327551,
#        -0.50206348, -0.50636256])

# %%
#try with ppo
#in ppo loop
#learning ratio of lya axis with nn
#retry calculate
