# %%
import gym
env = gym.make("LunarLander-v2", render_mode="human")
env.action_space.seed(42)

observation, info = env.reset(seed=42)

for _ in range(1000):
    observation, reward, terminated, truncated, info = env.step(env.action_space.sample())

    if terminated or truncated:
        observation, info = env.reset()

env.close()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[1], line 2
#       1 import gym
# ----> 2 env = gym.make("LunarLander-v2", render_mode="human")
#       3 env.action_space.seed(42)
#       5 observation, info = env.reset(seed=42)
#
# File ~/Dropbox/general_backup/anaconda3/envs/gen_env/lib/python3.10/site-packages/gym/envs/registration.py:235, in make(id, **kwargs)
#     234 def make(id, **kwargs):
# --> 235     return registry.make(id, **kwargs)
#
# File ~/Dropbox/general_backup/anaconda3/envs/gen_env/lib/python3.10/site-packages/gym/envs/registration.py:129, in EnvRegistry.make(self, path, **kwargs)
#     127     logger.info("Making new env: %s", path)
#     128 spec = self.spec(path)
# --> 129 env = spec.make(**kwargs)
#     130 return env
#
# File ~/Dropbox/general_backup/anaconda3/envs/gen_env/lib/python3.10/site-packages/gym/envs/registration.py:90, in EnvSpec.make(self, **kwargs)
#      88 else:
#      89     cls = load(self.entry_point)
# ---> 90     env = cls(**_kwargs)
#      92 # Make the environment aware of which spec it came from.
#      93 spec = copy.deepcopy(self)
#
# TypeError: LunarLander.__init__() got an unexpected keyword argument 'render_mode'

# %%
# Out:
# Package                    Version     Editable project location
# -------------------------- ----------- ------------------------------------------------------------
# absl-py                    1.3.0
# aiohttp                    3.8.4
# aiosignal                  1.3.1
# ale-py                     0.7.4
# appdirs                    1.4.4
# asttokens                  2.2.1
# async-generator            1.10
# async-timeout              4.0.2
# attrs                      22.2.0
# autograd                   1.6.2
# Automat                    22.10.0
# AutoROM                    0.4.2
# AutoROM.accept-rom-license 0.5.0
# backcall                   0.2.0
# beautifulsoup4             4.11.1
# bitarray                   2.7.3
# box2d-py                   2.3.5
# brotlipy                   0.7.0
# bs4                        0.0.1
# cachetools                 5.2.0
# certifi                    2022.12.7
# cffi                       1.15.1
# chardet                    5.1.0
# charset-normalizer         2.1.1
# chatGPT                    0.6.3
# click                      8.1.3
# cloudpickle                2.2.0
# colorama                   0.4.6
# comm                       0.1.2
# commonmark                 0.9.1
# constantly                 15.1.0
# contourpy                  1.0.6
# cryptography               38.0.4
# cssselect                  1.2.0
# cycler                     0.11.0
# Cython                     0.29.32
# data                       0.4
# datasets                   2.11.0
# debugpy                    1.6.4
# decorator                  4.4.2
# dill                       0.3.6
# dnspython                  2.3.0
# email-validator            1.3.1
# emmet-core                 0.51.0
# entrypoints                0.4
# evaluate                   0.4.0
# exceptiongroup             1.1.0
# executing                  1.2.0
# fasteners                  0.18
# filelock                   3.9.0
# Flask                      2.2.3
# fonttools                  4.38.0
# frozendict                 2.3.4
# frozenlist                 1.3.3
# fsspec                     2023.3.0
# fst-pso                    1.8.1
# funcsigs                   1.0.2
# funcy                      1.18
# future                     0.18.3
# FuzzyTM                    2.0.5
# gensim                     4.3.0
# glfw                       2.5.5
# google-auth                2.15.0
# google-auth-oauthlib       0.4.6
# greenlet                   2.0.1
# grpcio                     1.51.1
# gym                        0.21.0
# gym-notices                0.0.8
# h11                        0.14.0
# html5lib                   1.1
# huggingface-hub            0.13.2
# hyperlink                  21.0.0
# idna                       3.4
# imageio                    2.23.0
# imageio-ffmpeg             0.4.7
# importlib-metadata         4.13.0
# importlib-resources        5.10.2
# incremental                22.10.0
# iniconfig                  1.1.1
# ipykernel                  6.19.4
# ipython                    8.7.0
# itemadapter                0.7.0
# itemloaders                1.0.6
# itsdangerous               2.1.2
# jax                        0.4.14
# jaxlib                     0.4.14
# jedi                       0.18.2
# Jinja2                     3.1.2
# jmespath                   1.0.1
# joblib                     1.2.0
# jupyter_client             7.4.8
# jupyter_core               5.1.2
# karateclub                 1.3.3
# kiwisolver                 1.4.4
# latex                      0.7.0
# latexcodec                 2.0.1
# Levenshtein                0.20.9
# libtorrent                 2.0.7
# Lorenz-envs                0.0.1       /home/phu/Dropbox/general_backup/mastering_chaos/Lorenz_envs
# lxml                       4.9.2
# lz4                        4.3.2
# Markdown                   3.4.1
# MarkupSafe                 2.1.1
# matplotlib                 3.4.3
# matplotlib-inline          0.1.6
# miniful                    0.0.6
# ml-dtypes                  0.2.0
# monty                      2022.9.9
# moviepy                    1.0.3
# mp-api                     0.30.10
# mpmath                     1.3.0
# msgpack                    1.0.5
# mujoco                     2.2.0
# mujoco-py                  2.1.2.14
# multidict                  6.0.4
# multiprocess               0.70.14
# multitasking               0.0.11
# names                      0.3.0
# nest-asyncio               1.5.6
# networkx                   2.6.3
# nltk                       3.8.1
# node2vec                   0.4.6
# numexpr                    2.8.4
# numpy                      1.22.4
# nvidia-cublas-cu11         11.10.3.66
# nvidia-cuda-nvrtc-cu11     11.7.99
# nvidia-cuda-runtime-cu11   11.7.99
# nvidia-cudnn-cu11          8.5.0.96
# oauthlib                   3.2.2
# openai                     0.27.2
# opencv-python              4.7.0.68
# opt-einsum                 3.3.0
# outcome                    1.2.0
# packaging                  22.0
# palettable                 3.3.0
# pandas                     1.3.5
# parsel                     1.7.0
# parso                      0.8.3
# pdfminer.six               20221105
# pdfquery                   0.4.3
# pdfreader                  0.1.12
# pexpect                    4.8.0
# pickleshare                0.7.5
# Pillow                     9.4.0
# pip                        23.2.1
# platformdirs               2.6.2
# playwright                 1.31.1
# plotly                     5.13.1
# pluggy                     1.0.0
# pooch                      1.7.0
# proglog                    0.1.10
# prompt-toolkit             3.0.36
# Protego                    0.2.1
# protobuf                   3.20.3
# psutil                     5.9.4
# ptyprocess                 0.7.0
# pure-eval                  0.2.2
# py                         1.11.0
# pyarrow                    11.0.0
# pyasn1                     0.4.8
# pyasn1-modules             0.2.8
# pybtex                     0.24.0
# pycairo                    1.23.0
# pycparser                  2.21
# pycryptodome               3.17
# pydantic                   1.10.6
# PyDispatcher               2.0.7
# pyee                       9.0.4
# pyFUME                     0.2.25
# pygame                     2.1.0
# pyglet                     2.0.9
# Pygments                   2.14.0
# PyGSP                      0.5.1
# pyLDAvis                   3.4.0
# pymatgen                   2023.3.10
# PyOpenGL                   3.1.6
# pyOpenSSL                  23.0.0
# pyparsing                  3.0.9
# PyPDF2                     3.0.1
# pyperclip                  1.8.2
# pyquery                    2.0.0
# PySocks                    1.7.1
# pytest                     7.0.1
# python-dateutil            2.8.2
# python-frontmatter         1.0.0
# python-Levenshtein         0.20.9
# python-louvain             0.16
# python-pptx                0.6.21
# pytz                       2022.7.1
# PyYAML                     6.0
# pyzmq                      24.0.1
# queuelib                   1.6.2
# rapidfuzz                  2.15.0
# regex                      2022.10.31
# reportlab                  3.6.12
# requests                   2.28.1
# requests-file              1.5.1
# requests-oauthlib          1.3.1
# responses                  0.18.0
# rich                       13.0.0
# roman                      4.0
# rouge-score                0.1.2
# rsa                        4.9
# ruamel.yaml                0.17.21
# ruamel.yaml.clib           0.2.7
# scapy                      2.5.0
# scikit-learn               1.2.1
# scipy                      1.10.0
# Scrapy                     2.8.0
# seaborn                    0.12.2
# selenium                   4.8.2
# service-identity           21.1.0
# setuptools                 65.5.0
# shutilwhich                1.1.0
# simpful                    2.10.0
# six                        1.16.0
# smart-open                 6.3.0
# sniffio                    1.3.0
# sortedcontainers           2.4.0
# soupsieve                  2.3.2.post1
# spglib                     2.0.2
# SQLAlchemy                 2.0.11
# stable-baselines3          1.6.2
# stack-data                 0.6.2
# swig                       4.1.1
# sympy                      1.11.1
# ta                         0.10.2
# tabulate                   0.9.0
# tempdir                    0.7.1
# tenacity                   8.2.2
# tensorboard                2.11.0
# tensorboard-data-server    0.6.1
# tensorboard-plugin-wit     1.8.1
# threadpoolctl              3.1.0
# tiktoken                   0.3.2
# tldextract                 3.4.0
# tokenizers                 0.13.2
# tomli                      2.0.1
# torch                      1.13.1
# tornado                    6.2
# tqdm                       4.64.1
# traitlets                  5.8.0
# transformers               4.27.1
# trio                       0.22.0
# trio-websocket             0.9.2
# Twisted                    22.10.0
# typing_extensions          4.4.0
# tzdata                     2023.3
# uncertainties              3.1.7
# urllib3                    1.26.13
# w3lib                      2.1.1
# wcwidth                    0.2.5
# webencodings               0.5.1
# Werkzeug                   2.2.2
# wget                       3.2
# wheel                      0.37.1
# wsproto                    1.2.0
# XlsxWriter                 3.0.8
# xxhash                     3.2.0
# yarl                       1.8.2
# yfinance                   0.2.9
# zipp                       3.11.0
# zope.interface             5.5.2
